# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyab1111/MultiLexNorm-Challenge/blob/main/Danish/da_ln_seq2seq_biLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Embedding, Concatenate
from tensorflow.keras import Input, Model

# %% [markdown]
# Danish

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 30000  # Number of samples to train on.
data_path = '/content/drive/MyDrive/NLP/Lexical Normalisation/Multilexnorm Challenge/Danish/da.train.norm.txt'

# %% [markdown]
# Character encoding

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r") as f:
    lines = f.readlines()
for line in lines[: min(num_samples, len(lines) - 1)]:
  if line=='\n':
    continue
  else:
    input_text, target_text= line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)
# Out:
# Number of samples: 9392
# Number of unique input tokens: 152
# Number of unique output tokens: 154
# Max sequence length for inputs: 32
# Max sequence length for outputs: 35

# %%
input_texts
# Out:
# ['jeg',
#  'er',
#  'træt',
#  'af',
#  'GoT',
#  ',',
#  'jeg',
#  'synes',
#  'ikke',
#  'Tyrion',
#  'er',
#  'sjov',
#  'længere',
#  ',',
#  'jeg',
#  'synes',
#  'Daenaerys',
#  'er',
#  'meget',
#  'mindre',
#  'klog',
#  'og',
#  'sej',
#  'end',
#  'hun',
#  'plejede',
#  'at',
#  'være',
#  ',',
#  'og',
#  'jeg',
#  'kan',
#  'ikke',
#  'komme',
#  'mig',
#  'over',
#  'at',
#  'The',
#  'White',
#  'Walkers',
#  'bare',
#  'var',
#  'en',
#  'plotdevice',
#  'for',
#  'at',
#  'sætte',
#  'hende',
#  'ligeligt',
#  'op',
#  'mod',
#  'Cersei',
#  '-',
#  'og',
#  'Euron',
#  'som',
#  'jeg',
#  'ikke',
#  'magter',
#  '…',
#  'https://t.co/7l1DsA5dRG',
#  'Valget',
#  'Indefra',
#  ':',
#  'LA-profil',
#  'i',
#  'shitstorm',
#  'efter',
#  'forsøg',
#  'på',
#  'at',
#  'være',
#  'sjov',
#  'om',
#  'sine',
#  'hængebryster',
#  'Forhadt',
#  'socialdemokratisk',
#  'kandidat',
#  'er',
#  'blevet',
#  'reddet',
#  'af',
#  'teknikaliteter',
#  ',',
#  'mens',
#  'Liberal',
#  'Alliance',
#  'er',
#  'gået',
#  'i',
#  'det',
#  'lumre',
#  'hjørne',
#  '.',
#  'Velkommen',
#  'til',
#  'Valget',
#  'Indefra',
#  '.',
#  'https://t.co/Ew08bs813L',
#  'Markante',
#  'kredsformænd',
#  'om',
#  'næstformandsvalg',
#  ':',
#  'Frygt',
#  'ikke',
#  'det',
#  'ukendte',
#  'Formændene',
#  'for',
#  'Aalborg',
#  'og',
#  'Aarhus',
#  'Lærerforeninger',
#  'støtter',
#  'Morten',
#  'Refskov',
#  'ved',
#  'næstformandsvalget',
#  'i',
#  'DLF',
#  'i',
#  'næste',
#  'uge',
#  ',',
#  'skriver',
#  'de',
#  'i',
#  'dette',
#  'indlæg',
#  '.',
#  'Men',
#  'først',
#  'og',
#  'fremmest',
#  'er',
#  'budskabet',
#  ',',
#  'at',
#  'man',
#  'ikke',
#  '…',
#  'https://t.co/mYSBRh7zcW',
#  'Prøv',
#  'at',
#  'besøge',
#  'Frijsenborg',
#  'efterskole',
#  'hvor',
#  'man',
#  'har',
#  'løftet',
#  'hundredevis',
#  'af',
#  'børn',
#  'med',
#  'forskellige',
#  'indlæringsproblemer',
#  '.',
#  'Hørehæmmede',
#  'og',
#  'børn',
#  'og',
#  'unge',
#  'med',
#  'andre',
#  'diagnoser',
#  '.',
#  'med',
#  'kærlighed',
#  'sammenhold',
#  'friluftsliv',
#  'fokus',
#  'på',
#  'den',
#  'enkelte',
#  'elev',
#  '.',
#  'En',
#  'katastrofe',
#  'hvis',
#  'den',
#  'må',
#  'lukke',
#  '…',
#  'https://t.co/vYSrHF1UjS',
#  'Her',
#  'er',
#  'Lennart',
#  'Johanssons',
#  'interview',
#  'med',
#  'Tipsbladet',
#  'om',
#  ',',
#  'hvordan',
#  'han',
#  'kraftigt',
#  'mistænkte',
#  'præsidentvalget',
#  'i',
#  'Paris',
#  'i',
#  '1998',
#  'for',
#  'at',
#  'være',
#  'købt',
#  '.',
#  'Havde',
#  'ingen',
#  'kærlighed',
#  'til',
#  'overs',
#  'for',
#  'Sepp',
#  'Blatter',
#  'og',
#  'Michel',
#  'Platini',
#  '.',
#  'https://t.co/V1yobjLRoF',
#  '“',
#  'En',
#  'klassisk',
#  'GF',
#  '”',
#  '-',
#  'skal',
#  'vi',
#  'ikke',
#  'sende',
#  'lidt',
#  'kærlighed',
#  'afsted',
#  'til',
#  'Henrik',
#  'Ole',
#  'for',
#  'noget',
#  'der',
#  'blev',
#  'opfundet',
#  'af',
#  'Åkeby',
#  'og',
#  'Stiften',
#  'i',
#  '2003',
#  'og',
#  'var',
#  'en',
#  'stående',
#  'joke',
#  'blandt',
#  'fans',
#  'i',
#  '21',
#  'minutter',
#  'efterfølgende',
#  '❤',
#  '️',
#  'Vi',
#  'elsker',
#  'dig',
#  'Henrik',
#  'Ole',
#  '#ultratwitteragf',
#  '…',
#  'https://t.co/dnoFSp1EiR',
#  'Liverpool',
#  'nægtede',
#  'i',
#  'går',
#  'at',
#  'træne',
#  'på',
#  'Camp',
#  'Nou',
#  'i',
#  'frygt',
#  'for',
#  'at',
#  'blive',
#  'udspioneret',
#  'af',
#  'Barca',
#  '.',
#  'I',
#  'stedet',
#  'trænede',
#  'englænderne',
#  'i',
#  'al',
#  'hemmelighed',
#  'på',
#  'Espanyols',
#  'stadion',
#  'her',
#  'til',
#  'morgen',
#  '!',
#  'https://t.co/oazJCGSnH8',
#  'Men',
#  'det',
#  'er',
#  'jo',
#  'ikke',
#  'kun',
#  'udlændinge',
#  'der',
#  'rammes',
#  'ligesom',
#  'med',
#  'den',
#  'groteske',
#  'integrationsydelse',
#  'er',
#  'det',
#  'almindelige',
#  'danske',
#  'statsborgere',
#  'der',
#  'rammes',
#  'groft',
#  'pga',
#  'nogle',
#  'få',
#  'udlændinge',
#  'og',
#  'nogle',
#  'hysteriske',
#  'politikere',
#  'der',
#  'lever',
#  'af',
#  'frygt',
#  'og',
#  'had',
#  '!',
#  '#DF',
#  'kan',
#  'vist',
#  'ikke',
#  'klare',
#  'flere',
#  'tæsk',
#  'eller',
#  'hva',
#  '👊',
#  '😁',
#  '…',
#  'https://t.co/Y4XsCPwWWg',
#  'Islamistisk',
#  'terror',
#  'er',
#  'ikke',
#  'en',
#  'tilfældighed',
#  '.',
#  'Da',
#  'Muhamed',
#  'kom',
#  'til',
#  'Medina',
#  'og',
#  'blev',
#  'landevejsrøver',
#  ',',
#  'så',
#  'fik',
#  'han',
#  'følgere',
#  ',',
#  'fordi',
#  'slavekvinder',
#  ',',
#  'røvergods',
#  'og',
#  'frygt',
#  'var',
#  'tiltrækkende',
#  '.',
#  'https://t.co/6JA0y5psmQ',
#  'Kæmpe',
#  'overraskelse',
#  'i',
#  'Aarhus',
#  '-',
#  'Jovanovic',
#  'skifter',
#  'tilbage',
#  'til',
#  'AGF',
#  ',',
#  'og',
#  'lige',
#  'efter',
#  'det',
#  'blev',
#  'det',
#  'bekræftet',
#  ',',
#  'at',
#  'Kerim',
#  'Memija',
#  'bliver',
#  'lejet',
#  'ud',
#  'fra',
#  'Vejle',
#  'BK',
#  'til',
#  'Hobro',
#  'IK',
#  '.',
#  '#andellerej',
#  '#Transferdk',
#  'Kvinde',
#  ',',
#  'vær',
#  'smuk',
#  'og',
#  'hold',
#  'din',
#  'mund',
#  '!',
#  'MissDK',
#  'er',
#  'toppen',
#  'af',
#  'pyramiden',
#  'i',
#  'præstationsræset',
#  'som',
#  'unge',
#  'knækker',
#  'nakken',
#  'på',
#  '.',
#  'Du',
#  'har',
#  'én',
#  'opgave',
#  ':',
#  'at',
#  'opretholde',
#  'illusionen',
#  'om',
#  'den',
#  'søde',
#  'unge',
#  'kvinde',
#  ',',
#  'mens',
#  'du',
#  'produktgøres',
#  'og',
#  'lægger',
#  'krop',
#  'til',
#  'grov',
#  'overtrædelse',
#  'af',
#  'dine',
#  'rettigheder',
#  'https://t.co/sgmgtBHKrI',
#  'på',
#  '63',
#  'er',
#  '‘',
#  'kær',
#  'lig',
#  'heds',
#  'flygt',
#  'ning',
#  '’',
#  ':',
#  'Blev',
#  'sæso',
#  'n',
#  'ar',
#  'bej',
#  'der',
#  'i',
#  'Frankrig',
#  'for',
#  'at',
#  'kunne',
#  'bo',
#  'med',
#  'sit',
#  'livs',
#  'kærlighed',
#  '”',
#  'Her',
#  'er',
#  'syv',
#  'gode',
#  'tilbud',
#  'til',
#  'næste',
#  'uge',
#  ':',
#  'Så',
#  'er',
#  'Antonio',
#  'Banderas',
#  'igen',
#  'i',
#  'hænderne',
#  'på',
#  'Pedro',
#  'Almodóvar',
#  'Glæd',
#  'dig',
#  'til',
#  'en',
#  'veloplagt',
#  'Antonio',
#  'Banderas',
#  'i',
#  'Almodóvars',
#  'erindringsfilm',
#  '’',
#  'Smerte',
#  'og',
#  'ære',
#  '’',
#  '.',
#  'Kristian',
#  'Bang',
#  'Foss',
#  'er',
#  'klar',
#  'med',
#  'sin',
#  'tredje',
#  'roman',
#  ',',
#  'mens',
#  'Suzanne',
#  'Brøgger',
#  '…',
#  'https://t.co/KMDKyVsANX',
#  'Sådan',
#  '!',
#  'D',
#  'r',
#  'lige',
#  'præcis',
#  'den',
#  'rigtige',
#  'analyse',
#  '.',
#  'De',
#  'lavtlønnede',
#  'vælgere',
#  'r',
#  'gået',
#  'over',
#  't',
#  'DF',
#  'af',
#  'frygt',
#  'for',
#  '1ustoppelig',
#  'nedskæring',
#  'af',
#  'velfærden',
#  ',',
#  'som',
#  'de',
#  'fik',
#  'skudt',
#  'i',
#  'skoen',
#  'var',
#  'indvandrernes',
#  'skyld',
#  '.',
#  'Overbevist',
#  'om',
#  'at',
#  '@Spolitik',
#  'højredrejning',
#  'ik',
#  'havde',
#  'været',
#  'nødvendig',
#  ',',
#  'hvis',
#  'de',
#  'havde',
#  'mer',
#  'rød',
#  'politik',
#  '…',
#  'https://t.co/oIbSoFQa0S',
#  'Christoffer',
#  'Berdals',
#  'iscenesættelse',
#  'og',
#  'bearbejdselse',
#  'af',
#  'Shakespeares',
#  '”',
#  'Helligtrekongersaften',
#  '”',
#  'har',
#  'både',
#  'kærlighed',
#  ',',
#  'kapow',
#  'og',
#  'kønsforveksling',
#  '.',
#  'https://t.co/vgC7QinfKf…',
#  'https://t.co/UPeEh1UqJX',
#  'Selvfølglig',
#  'skal',
#  'der',
#  'tilføres',
#  'arbejdskraft',
#  'udefra',
#  ',',
#  'især',
#  'hvis',
#  'man',
#  'vil',
#  'sikre',
#  'DK',
#  'velfærd',
#  'og',
#  'tidligere',
#  'tilbagetrækningsmuligheder',
#  'på',
#  'arb.markedet',
#  '.',
#  '#dkpol',
#  'https://t.co/fWCTo5KlhF',
#  'Hvem',
#  'skulle',
#  'ellers',
#  'være',
#  'blevet',
#  'nomineret',
#  '?',
#  'Jeg',
#  'kunne',
#  'tænke',
#  'på',
#  'Lupita',
#  "Nyong'o",
#  'og',
#  'Yeo-jeong',
#  'Jo',
#  ',',
#  'som',
#  'måske',
#  'er',
#  'snubs',
#  '.',
#  'Tror',
#  'du',
#  ',',
#  'det',
#  'er',
#  'fordi',
#  'Akademiet',
#  'er',
#  'racistisk',
#  '?',
#  '…',
#  'https://t.co/veJldmuRlD',
#  '.',
#  'Gnavpot',
#  '2',
#  'ved',
#  'du',
#  ',',
#  'at',
#  'der',
#  'idag',
#  'faktisk',
#  'er',
#  'flere',
#  'danske',
#  'lastbiler',
#  ',',
#  'der',
#  'kører',
#  'over',
#  'grænsen',
#  'end',
#  'i',
#  '2009',
#  '?',
#  'Tjek',
#  'Vejdirektoratets',
#  'tal',
#  ':',
#  'østeuropæere',
#  'erobrer',
#  'markedsandele',
#  'fra',
#  'tyskere',
#  'og',
#  'andre',
#  'EU-landes',
#  'chauffører',
#  '.',
#  'Men',
#  'stadig',
#  'meget',
#  'lille',
#  'del',
#  'af',
#  'total',
#  'transport',
#  'i',
#  'DK',
#  '.',
#  'Så',
#  'drop',
#  'frygt',
#  '#dkpol',
#  '…',
#  'https://t.co/JMyZsUm7Zy',
#  'DR',
#  'må',
#  'da',
#  'virkelig',
#  'være',
#  'på',
#  'røven',
#  '?',
#  'De',
#  'har',
#  'lige',
#  'lukket',
#  'ellers',
#  'udemærkede',
#  'DrK',
#  'og',
#  'Dr3',
#  '.',
#  'Tilbage',
#  'sidder',
#  'vi',
#  'med',
#  'Dr1',
#  'og',
#  'Dr2',
#  ',',
#  'som',
#  'i',
#  'aften',
#  'sender',
#  'Disney',
#  'Sjov',
#  ',',
#  'Genudsendelser',
#  'med',
#  'Een',
#  'gang',
#  'strømer',
#  'og',
#  'Cirkusrevy',
#  'fra',
#  '2010',
#  '...',
#  'LUK',
#  'LORTET',
#  '!',
#  '#Dkpol',
#  'Det',
#  'er',
#  'et',
#  'af',
#  'de',
#  'spilforslag',
#  ',',
#  'der',
#  'ikke',
#  'er',
#  'helt',
#  'så',
#  'sjov',
#  'at',
#  'lave',
#  '...',
#  'Men',
#  'vi',
#  'er',
#  'ude',
#  'i',
#  'et',
#  'spiltil',
#  'odds',
#  '2.75',
#  '.',
#  'https://t.co/YmJP2YzfrP…',
#  'https://t.co/9aQGMg0IRP',
#  'Eksilårene',
#  'læser',
#  'Shahrnush',
#  'Parsipurs',
#  'roman',
#  '‘',
#  'Kvinder',
#  'uden',
#  'mænd',
#  '’',
#  ',',
#  'hvor',
#  'magi',
#  ',',
#  'frigørelse',
#  'og',
#  'kærlighed',
#  'udfolder',
#  'sig',
#  'i',
#  'en',
#  'meget',
#  'stor',
#  'læseoplevelse',
#  'i',
#  'en',
#  ',',
#  'hvad',
#  'sidetal',
#  'angår',
#  ',',
#  'lille',
#  'bog',
#  '.',
#  'https://t.co/LQOD5eGMMz',
#  'Nu',
#  'hvor',
#  'kedo',
#  'ikke',
#  'er',
#  'aktive',
#  'længere',
#  ',',
#  'må',
#  'manageren',
#  '(',
#  'og',
#  'vores',
#  'største',
#  'groupie',
#  ')',
#  'jo',
#  'kaste',
#  'sin',
#  'kærlighed',
#  'over',
#  'nogle',
#  'andre',
#  '.',
#  'Og',
#  'det',
#  'blev',
#  'så',
#  'et',
#  'eller',
#  'andet',
#  'upcoming',
#  'efterskoleband',
#  'ved',
#  'navn',
#  '@kashmirofficial',
#  '.',
#  'Hmm',
#  ',',
#  'vi',
#  'kender',
#  'dem',
#  'ikke',
#  'rigtigt',
#  ',',
#  'men',
#  'deres',
#  'bassist',
#  '(',
#  'bass-Mads',
#  ')',
#  'ser',
#  'cool',
#  'ud',
#  '😎',
#  '.',
#  '…',
#  'https://t.co/y14gikUxD3',
#  'Overraskede',
#  'tobakstyv',
#  'i',
#  'hvid',
#  'skjorte',
#  'på',
#  'Søvænget',
#  'Faldsled',
#  ':',
#  'Beboeren',
#  'i',
#  'et',
#  'hjem',
#  'på',
#  'Søvænget',
#  'i',
#  'Faldsled',
#  'fik',
#  'sig',
#  'en',
#  'grim',
#  'overraskelse',
#  ',',
#  'da',
#  'vedkommende',
#  'kom',
#  'hjem',
#  'og',
#  'overraskede',
#  'en',
#  'tyv',
#  'i',
#  'sin',
#  'bolig',
#  '.',
#  'Gerningsmanden',
#  'var',
#  'kommet',
#  'ind',
#  'gennem',
#  'en',
#  'ulåst',
#  'hoveddør',
#  ',',
#  'og',
#  '…',
#  'https://t.co/4miGmlygiL',
#  'Jeg',
#  'fik',
#  'en',
#  'uddannelse',
#  ',',
#  'blev',
#  'skilt',
#  ',',
#  'fik',
#  'stres',
#  ',',
#  'fandt',
#  'min',
#  'livsmission',
#  ',',
#  'mødte',
#  'mit',
#  'livs',
#  'kærlighed',
#  ',',
#  'stiftede',
#  'DigiPippi',
#  'og',
#  'meget',
#  'andet',
#  '😘',
#  '…',
#  'https://t.co/VhAmdnSxxH',
#  'Jeg',
#  'ved',
#  'godt',
#  'jeg',
#  'ikke',
#  'er',
#  'typisk',
#  '...',
#  'Men',
#  'jeg',
#  'ææælsker',
#  'altså',
#  'at',
#  'ræse',
#  'afsted',
#  'med',
#  'Crimson',
#  'og',
#  'Translation',
#  'Theory',
#  'close',
#  'up',
#  'Og',
#  'med',
#  'Bygones',
#  'og',
#  ...]

# %% [markdown]
# encoder_input_data is a 3D array of shape (num_pairs, max_english_sentence_length, num_english_characters) containing a one-hot vectorization of the English sentences.
#
# decoder_input_data is a 3D array of shape (num_pairs, max_french_sentence_length, num_french_characters) containg a one-hot vectorization of the French sentences.
#
# decoder_target_data is the same as decoder_input_data but offset by one timestep. decoder_target_data[:, t, :] will be the same as decoder_input_data[:, t + 1, :].

# %%
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

# %% [markdown]
# one hot rep

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[',']] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, (t + 1):, target_token_index[',']] = 1.0
    decoder_target_data[i, t:, target_token_index[',']] = 1.0

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = Bidirectional(LSTM(latent_dim, return_state=True, return_sequences=True))
encoder_outputs1, forw_state_h, forw_state_c, back_state_h, back_state_c = encoder(encoder_inputs)

state_h = Concatenate()([forw_state_h, back_state_h])
state_c = Concatenate()([forw_state_c, back_state_c])

encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM((2*latent_dim), return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 118/118 [==============================] - 13s 31ms/step - loss: 0.7605 - accuracy: 0.8292 - val_loss: 0.5570 - val_accuracy: 0.8472
# Epoch 2/100
# 118/118 [==============================] - 2s 21ms/step - loss: 0.4991 - accuracy: 0.8694 - val_loss: 0.4263 - val_accuracy: 0.8812
# Epoch 3/100
# 118/118 [==============================] - 2s 21ms/step - loss: 0.3666 - accuracy: 0.9068 - val_loss: 0.3202 - val_accuracy: 0.9155
# Epoch 4/100
# 118/118 [==============================] - 3s 21ms/step - loss: 0.2816 - accuracy: 0.9266 - val_loss: 0.1980 - val_accuracy: 0.9480
# Epoch 5/100
# 118/118 [==============================] - 3s 21ms/step - loss: 0.1939 - accuracy: 0.9482 - val_loss: 0.1596 - val_accuracy: 0.9592
# Epoch 6/100
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1431 - accuracy: 0.9623 - val_loss: 0.1137 - val_accuracy: 0.9717
# Epoch 7/100
# 118/118 [==============================] - 3s 21ms/step - loss: 0.1116 - accuracy: 0.9713 - val_loss: 0.1175 - val_accuracy: 0.9698
# Epoch 8/100
# 118/118 [==============================] - 3s 21ms/step - loss: 0.0893 - accuracy: 0.9773 - val_loss: 0.0939 - val_accuracy: 0.9775
# Epoch 9/100
# 118/118 [==============================] - 3s 21ms/step - loss: 0.0753 - accuracy: 0.9808 - val_loss: 0.0835 - val_accuracy: 0.9797
# Epoch 10/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0646 - accuracy: 0.9837 - val_loss: 0.0845 - val_accuracy: 0.9794
# Epoch 11/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0561 - accuracy: 0.9860 - val_loss: 0.0736 - val_accuracy: 0.9825
# Epoch 12/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0503 - accuracy: 0.9875 - val_loss: 0.0675 - val_accuracy: 0.9840
# Epoch 13/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0446 - accuracy: 0.9889 - val_loss: 0.0668 - val_accuracy: 0.9838
# Epoch 14/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0400 - accuracy: 0.9901 - val_loss: 0.0649 - val_accuracy: 0.9846
# Epoch 15/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0363 - accuracy: 0.9908 - val_loss: 0.0634 - val_accuracy: 0.9857
# Epoch 16/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0329 - accuracy: 0.9919 - val_loss: 0.0664 - val_accuracy: 0.9846
# Epoch 17/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0299 - accuracy: 0.9924 - val_loss: 0.0645 - val_accuracy: 0.9852
# Epoch 18/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0274 - accuracy: 0.9929 - val_loss: 0.0641 - val_accuracy: 0.9860
# Epoch 19/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0247 - accuracy: 0.9938 - val_loss: 0.0654 - val_accuracy: 0.9862
# Epoch 20/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0231 - accuracy: 0.9940 - val_loss: 0.0598 - val_accuracy: 0.9866
# Epoch 21/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0210 - accuracy: 0.9945 - val_loss: 0.0642 - val_accuracy: 0.9858
# Epoch 22/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0188 - accuracy: 0.9950 - val_loss: 0.0653 - val_accuracy: 0.9865
# Epoch 23/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0173 - accuracy: 0.9955 - val_loss: 0.0637 - val_accuracy: 0.9860
# Epoch 24/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 0.0643 - val_accuracy: 0.9865
# Epoch 25/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0141 - accuracy: 0.9962 - val_loss: 0.0673 - val_accuracy: 0.9867
# Epoch 26/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0131 - accuracy: 0.9965 - val_loss: 0.0637 - val_accuracy: 0.9867
# Epoch 27/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.0657 - val_accuracy: 0.9868
# Epoch 28/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 0.0702 - val_accuracy: 0.9859
# Epoch 29/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0098 - accuracy: 0.9975 - val_loss: 0.0656 - val_accuracy: 0.9868
# Epoch 30/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0698 - val_accuracy: 0.9865
# Epoch 31/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0077 - accuracy: 0.9981 - val_loss: 0.0694 - val_accuracy: 0.9853
# Epoch 32/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.0644 - val_accuracy: 0.9866
# Epoch 33/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.0725 - val_accuracy: 0.9859
# Epoch 34/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.0653 - val_accuracy: 0.9873
# Epoch 35/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.0643 - val_accuracy: 0.9873
# Epoch 36/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.0694 - val_accuracy: 0.9871
# Epoch 37/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.0672 - val_accuracy: 0.9868
# Epoch 38/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0684 - val_accuracy: 0.9866
# Epoch 39/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.0694 - val_accuracy: 0.9869
# Epoch 40/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.0687 - val_accuracy: 0.9871
# Epoch 41/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0678 - val_accuracy: 0.9873
# Epoch 42/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0726 - val_accuracy: 0.9865
# Epoch 43/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0686 - val_accuracy: 0.9870
# Epoch 44/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0699 - val_accuracy: 0.9868
# Epoch 45/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0703 - val_accuracy: 0.9868
# Epoch 46/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0684 - val_accuracy: 0.9868
# Epoch 47/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0696 - val_accuracy: 0.9869
# Epoch 48/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0717 - val_accuracy: 0.9871
# Epoch 49/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0706 - val_accuracy: 0.9876
# Epoch 50/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0717 - val_accuracy: 0.9873
# Epoch 51/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0697 - val_accuracy: 0.9876
# Epoch 52/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0729 - val_accuracy: 0.9869
# Epoch 53/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0796 - val_accuracy: 0.9853
# Epoch 54/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0744 - val_accuracy: 0.9871
# Epoch 55/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0710 - val_accuracy: 0.9872
# Epoch 56/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0733 - val_accuracy: 0.9869
# Epoch 57/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0722 - val_accuracy: 0.9870
# Epoch 58/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0735 - val_accuracy: 0.9871
# Epoch 59/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0788 - val_accuracy: 0.9863
# Epoch 60/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0746 - val_accuracy: 0.9871
# Epoch 61/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0757 - val_accuracy: 0.9871
# Epoch 62/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0740 - val_accuracy: 0.9874
# Epoch 63/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0756 - val_accuracy: 0.9868
# Epoch 64/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0764 - val_accuracy: 0.9867
# Epoch 65/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0787 - val_accuracy: 0.9867
# Epoch 66/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0832 - val_accuracy: 0.9859
# Epoch 67/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0785 - val_accuracy: 0.9865
# Epoch 68/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0746 - val_accuracy: 0.9873
# Epoch 69/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0756 - val_accuracy: 0.9870
# Epoch 70/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0785 - val_accuracy: 0.9865
# Epoch 71/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0779 - val_accuracy: 0.9865
# Epoch 72/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0786 - val_accuracy: 0.9871
# Epoch 73/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0762 - val_accuracy: 0.9872
# Epoch 74/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0776 - val_accuracy: 0.9868
# Epoch 75/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0789 - val_accuracy: 0.9868
# Epoch 76/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0791 - val_accuracy: 0.9864
# Epoch 77/100
# 118/118 [==============================] - 3s 23ms/step - loss: 8.7733e-04 - accuracy: 0.9998 - val_loss: 0.0823 - val_accuracy: 0.9865
# Epoch 78/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0795 - val_accuracy: 0.9867
# Epoch 79/100
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0811 - val_accuracy: 0.9868
# Epoch 80/100
# 118/118 [==============================] - 3s 22ms/step - loss: 9.4586e-04 - accuracy: 0.9998 - val_loss: 0.0864 - val_accuracy: 0.9860
# Epoch 81/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.9205e-04 - accuracy: 0.9998 - val_loss: 0.0803 - val_accuracy: 0.9870
# Epoch 82/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.3554e-04 - accuracy: 0.9998 - val_loss: 0.0813 - val_accuracy: 0.9873
# Epoch 83/100
# 118/118 [==============================] - 3s 22ms/step - loss: 9.4654e-04 - accuracy: 0.9998 - val_loss: 0.0819 - val_accuracy: 0.9868
# Epoch 84/100
# 118/118 [==============================] - 3s 22ms/step - loss: 9.1564e-04 - accuracy: 0.9998 - val_loss: 0.0791 - val_accuracy: 0.9873
# Epoch 85/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.6184e-04 - accuracy: 0.9998 - val_loss: 0.0850 - val_accuracy: 0.9866
# Epoch 86/100
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0820 - val_accuracy: 0.9867
# Epoch 87/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.1182e-04 - accuracy: 0.9998 - val_loss: 0.0803 - val_accuracy: 0.9870
# Epoch 88/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.0399e-04 - accuracy: 0.9998 - val_loss: 0.0822 - val_accuracy: 0.9866
# Epoch 89/100
# 118/118 [==============================] - 3s 22ms/step - loss: 7.3360e-04 - accuracy: 0.9998 - val_loss: 0.0868 - val_accuracy: 0.9864
# Epoch 90/100
# 118/118 [==============================] - 3s 22ms/step - loss: 9.9420e-04 - accuracy: 0.9998 - val_loss: 0.0840 - val_accuracy: 0.9866
# Epoch 91/100
# 118/118 [==============================] - 3s 22ms/step - loss: 7.6693e-04 - accuracy: 0.9998 - val_loss: 0.0862 - val_accuracy: 0.9865
# Epoch 92/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.1949e-04 - accuracy: 0.9998 - val_loss: 0.0838 - val_accuracy: 0.9865
# Epoch 93/100
# 118/118 [==============================] - 3s 22ms/step - loss: 7.6084e-04 - accuracy: 0.9998 - val_loss: 0.0834 - val_accuracy: 0.9872
# Epoch 94/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.1562e-04 - accuracy: 0.9998 - val_loss: 0.0860 - val_accuracy: 0.9871
# Epoch 95/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.5685e-04 - accuracy: 0.9998 - val_loss: 0.0841 - val_accuracy: 0.9866
# Epoch 96/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.3960e-04 - accuracy: 0.9998 - val_loss: 0.0846 - val_accuracy: 0.9869
# Epoch 97/100
# 118/118 [==============================] - 3s 22ms/step - loss: 7.4645e-04 - accuracy: 0.9998 - val_loss: 0.0827 - val_accuracy: 0.9872
# Epoch 98/100
# 118/118 [==============================] - 3s 22ms/step - loss: 7.2115e-04 - accuracy: 0.9998 - val_loss: 0.0842 - val_accuracy: 0.9869
# Epoch 99/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.4261e-04 - accuracy: 0.9998 - val_loss: 0.0881 - val_accuracy: 0.9861
# Epoch 100/100
# 118/118 [==============================] - 3s 22ms/step - loss: 8.3890e-04 - accuracy: 0.9998 - val_loss: 0.0859 - val_accuracy: 0.9868
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2s/assets
# INFO:tensorflow:Assets written to: s2s/assets

# %%
from tensorflow.keras.utils import plot_model
plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)

# %%
import matplotlib.pyplot as plt
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# testing with validation

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs1, forw_state_h, forw_state_c, back_state_h, back_state_c = model.layers[1].output # lstm_1
state_h_enc = Concatenate()([forw_state_h, back_state_h])
state_c_enc = Concatenate()([forw_state_c, back_state_c])
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=((2*latent_dim),), name="input_4")
decoder_state_input_c = keras.Input(shape=((2*latent_dim),), name="input_5")
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[5]
initial_state=decoder_states_inputs
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(decoder_inputs, initial_state=initial_state)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[6]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: jeg
# Decoded sentence: jeg
#
# -
# Input sentence: er
# Decoded sentence: er
#
# -
# Input sentence: træt
# Decoded sentence: træt
#
# -
# Input sentence: af
# Decoded sentence: af
#
# -
# Input sentence: GoT
# Decoded sentence: GoT
#
# -
# Input sentence: ,
# Decoded sentence: ,
#
# -
# Input sentence: jeg
# Decoded sentence: jeg
#
# -
# Input sentence: synes
# Decoded sentence: synes
#
# -
# Input sentence: ikke
# Decoded sentence: ikke
#
# -
# Input sentence: Tyrion
# Decoded sentence: Tyrion
#
# -
# Input sentence: er
# Decoded sentence: er
#
# -
# Input sentence: sjov
# Decoded sentence: sjov
#
# -
# Input sentence: længere
# Decoded sentence: længere
#
# -
# Input sentence: ,
# Decoded sentence: ,
#
# -
# Input sentence: jeg
# Decoded sentence: jeg
#
# -
# Input sentence: synes
# Decoded sentence: synes
#
# -
# Input sentence: Daenaerys
# Decoded sentence: Daenaerys
#
# -
# Input sentence: er
# Decoded sentence: er
#
# -
# Input sentence: meget
# Decoded sentence: meget
#
# -
# Input sentence: mindre
# Decoded sentence: mindre
#
# -
# Input sentence: klog
# Decoded sentence: klog
#
# -
# Input sentence: og
# Decoded sentence: og
#
# -
# Input sentence: sej
# Decoded sentence: sej
#
# -
# Input sentence: end
# Decoded sentence: end
#
# -
# Input sentence: hun
# Decoded sentence: hun
#
# -
# Input sentence: plejede
# Decoded sentence: plejede
#
# -
# Input sentence: at
# Decoded sentence: at
#
# -
# Input sentence: være
# Decoded sentence: være
#
# -
# Input sentence: ,
# Decoded sentence: ,
#
# -
# Input sentence: og
# Decoded sentence: og
#
# -
# Input sentence: jeg
# Decoded sentence: jeg
#
# -
# Input sentence: kan
# Decoded sentence: kan
#
# -
# Input sentence: ikke
# Decoded sentence: ikke
#
# -
# Input sentence: komme
# Decoded sentence: komme
#
# -
# Input sentence: mig
# Decoded sentence: mig
#
# -
# Input sentence: over
# Decoded sentence: over
#
# -
# Input sentence: at
# Decoded sentence: at
#
# -
# Input sentence: The
# Decoded sentence: The
#
# -
# Input sentence: White
# Decoded sentence: White
#
# -
# Input sentence: Walkers
# Decoded sentence: Walkers
#
# -
# Input sentence: bare
# Decoded sentence: bare
#
# -
# Input sentence: var
# Decoded sentence: var
#
# -
# Input sentence: en
# Decoded sentence: en
#
# -
# Input sentence: plotdevice
# Decoded sentence: plotdevice
#
# -
# Input sentence: for
# Decoded sentence: for
#
# -
# Input sentence: at
# Decoded sentence: at
#
# -
# Input sentence: sætte
# Decoded sentence: sætte
#
# -
# Input sentence: hende
# Decoded sentence: hende
#
# -
# Input sentence: ligeligt
# Decoded sentence: ligeligt
#
# -
# Input sentence: op
# Decoded sentence: op
#
# -
# Input sentence: mod
# Decoded sentence: mod
#
# -
# Input sentence: Cersei
# Decoded sentence: Cersei
#
# -
# Input sentence: -
# Decoded sentence: -
#
# -
# Input sentence: og
# Decoded sentence: og
#
# -
# Input sentence: Euron
# Decoded sentence: Euron
#
# -
# Input sentence: som
# Decoded sentence: som
#
# -
# Input sentence: jeg
# Decoded sentence: jeg
#
# -
# Input sentence: ikke
# Decoded sentence: ikke
#
# -
# Input sentence: magter
# Decoded sentence: magter
#
# -
# Input sentence: …
# Decoded sentence: …
#
# -
# Input sentence: https://t.co/7l1DsA5dRG
# Decoded sentence: https://t.co/7l1DsA5dRG
#
# -
# Input sentence: Valget
# Decoded sentence: valget
#
# -
# Input sentence: Indefra
# Decoded sentence: indefra
#
# -
# Input sentence: :
# Decoded sentence: :
#
# -
# Input sentence: LA-profil
# Decoded sentence: LA-profil
#
# -
# Input sentence: i
# Decoded sentence: i
#
# -
# Input sentence: shitstorm
# Decoded sentence: shitstorm
#
# -
# Input sentence: efter
# Decoded sentence: efter
#
# -
# Input sentence: forsøg
# Decoded sentence: forsøg
#
# -
# Input sentence: på
# Decoded sentence: på
#
# -
# Input sentence: at
# Decoded sentence: at
#
# -
# Input sentence: være
# Decoded sentence: være
#
# -
# Input sentence: sjov
# Decoded sentence: sjov
#
# -
# Input sentence: om
# Decoded sentence: om
#
# -
# Input sentence: sine
# Decoded sentence: sine
#
# -
# Input sentence: hængebryster
# Decoded sentence: hængebryster
#
# -
# Input sentence: Forhadt
# Decoded sentence: forhadt
#
# -
# Input sentence: socialdemokratisk
# Decoded sentence: socialdemokratisk
#
# -
# Input sentence: kandidat
# Decoded sentence: kandidat
#
# -
# Input sentence: er
# Decoded sentence: er
#
# -
# Input sentence: blevet
# Decoded sentence: blevet
#
# -
# Input sentence: reddet
# Decoded sentence: reddet
#
# -
# Input sentence: af
# Decoded sentence: af
#
# -
# Input sentence: teknikaliteter
# Decoded sentence: teknikaliterer
#
# -
# Input sentence: ,
# Decoded sentence: ,
#
# -
# Input sentence: mens
# Decoded sentence: mens
#
# -
# Input sentence: Liberal
# Decoded sentence: Liberal
#
# -
# Input sentence: Alliance
# Decoded sentence: Alliance
#
# -
# Input sentence: er
# Decoded sentence: er
#
# -
# Input sentence: gået
# Decoded sentence: gået
#
# -
# Input sentence: i
# Decoded sentence: i
#
# -
# Input sentence: det
# Decoded sentence: det
#
# -
# Input sentence: lumre
# Decoded sentence: lumre
#
# -
# Input sentence: hjørne
# Decoded sentence: hjørne
#
# -
# Input sentence: .
# Decoded sentence: .
#
# -
# Input sentence: Velkommen
# Decoded sentence: Velkommen
#
# -
# Input sentence: til
# Decoded sentence: til
#
# -
# Input sentence: Valget
# Decoded sentence: valget
#
# -
# Input sentence: Indefra
# Decoded sentence: indefra
#
# -
# Input sentence: .
# Decoded sentence: .
