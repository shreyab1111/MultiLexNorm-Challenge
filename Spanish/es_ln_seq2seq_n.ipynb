# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyab1111/MultiLexNorm-Challenge/blob/main/es_ln_seq2seq_n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Spanish

# %%
batch_size = 64  # Batch size for training.
epochs = 150  # Number of epochs to train for.
latent_dim = 68  # Latent dimensionality of the encoding space.
num_samples = 20000  # Number of samples to train on.
data_path = '/content/drive/MyDrive/NLP/Lexical Normalisation/Multilexnorm Challenge/Spanish/es.train.norm.txt'

# %% [markdown]
# Character encoding

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r") as f:
    lines = f.readlines()
for line in lines[: min(num_samples, len(lines) - 1)]:
  if line=='\n':
    continue
  else:
    input_text, target_text= line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)
# Out:
# Number of samples: 7189
# Number of unique input tokens: 80
# Number of unique output tokens: 80
# Max sequence length for inputs: 47
# Max sequence length for outputs: 36

# %%
input_texts
# Out:
# ['la',
#  'gente',
#  'no',
#  'cambia',
#  'por',
#  'que',
#  'quiere,',
#  'sino',
#  'por',
#  'que',
#  'le',
#  'hicieron',
#  'daño',
#  'y',
#  'se',
#  'vio',
#  'obligada',
#  'a',
#  'dejar',
#  'de',
#  'ser',
#  'quien',
#  'era',
#  '..',
#  'hoy',
#  'llevo',
#  'la',
#  'camiseta',
#  'de',
#  'batman',
#  'jdjejdkahflwkdjwpvqh',
#  '.',
#  'el',
#  'siestón',
#  'que',
#  'me',
#  'voy',
#  'a',
#  'echar',
#  'hoy',
#  'va',
#  'a',
#  'ser',
#  'digno...!',
#  '@xheartbreaker_',
#  'ay',
#  'dios,',
#  'hoy',
#  'acabo',
#  'en',
#  'el',
#  'hospital',
#  'por',
#  'ataques.',
#  'esperando',
#  'walking',
#  'dead',
#  '.',
#  'a',
#  'ver',
#  'como',
#  'acaba...',
#  '@ursulaa5',
#  'me',
#  'esquivocao',
#  'y',
#  'estoy',
#  'en',
#  'el',
#  'donald',
#  'del',
#  'piolin',
#  'ya',
#  'estoy',
#  'yendo.',
#  'http://t.co/q9kq4daxfv',
#  '@cristinasorisa',
#  '@lorenahl16',
#  '@rocioortiz954',
#  '@pilar_2212',
#  '@silvia_sg_95',
#  'de',
#  'paluegos',
#  'del',
#  'fanegol',
#  'jajajajajajajajajjajajajajajaja',
#  'me',
#  'meoooo',
#  '*',
#  'vega',
#  'del',
#  'codorno',
#  '*',
#  'actualizado:',
#  '02-04-2013',
#  '05:02',
#  'utc',
#  '*',
#  'temperatura:',
#  '2,1',
#  'ºc',
#  '(',
#  'máx.',
#  ':',
#  '2,8',
#  '/',
#  'mín.',
#  ':',
#  '2,1',
#  ')',
#  '*',
#  'humedad:...',
#  'http://t.co/yvq0k7mws4',
#  '@loresinte',
#  '@rubitamalaguita',
#  '@bea_diamonds',
#  'miedo',
#  'me',
#  'da',
#  'chicas!!',
#  'miedo',
#  'me',
#  'da',
#  'xq',
#  'el',
#  'año',
#  'pasao',
#  'acabamos',
#  'to',
#  'jamas',
#  'porai',
#  'jajaja',
#  '@danisantostv',
#  'a',
#  'mi',
#  'sobre',
#  'todo',
#  'la',
#  'reacción',
#  'de',
#  'miriam',
#  '#noentiendonada',
#  '#miriampasucasa',
#  '#gh14',
#  '@amaya_fitness',
#  'y',
#  'q',
#  'es',
#  'mejor,',
#  'lentas',
#  'o',
#  'rapidas',
#  'las',
#  'repeticiones?',
#  'no',
#  'se',
#  'que',
#  'responderte!',
#  '..',
#  'ok?',
#  'suena',
#  'borde,',
#  'vale?',
#  'tambien',
#  'suena',
#  'borde,',
#  'gracias?',
#  'no',
#  'lo',
#  'merece,',
#  'que',
#  'te',
#  'digo?..',
#  'pues',
#  'mejor',
#  'me',
#  'callo',
#  'y',
#  'fin.',
#  '#lavidaesmásfácilcuando',
#  'te',
#  'has',
#  'fumado',
#  'unos',
#  'porros,',
#  'no',
#  'hay',
#  'problemas',
#  'ni',
#  'preocupaciones.',
#  'voy',
#  'aaa',
#  'seguir',
#  'el',
#  'camino',
#  'con',
#  'el',
#  'mooovil',
#  'apagado',
#  'que',
#  'caasi',
#  'no',
#  'tengo',
#  'bateriaa',
#  '.',
#  'adioos',
#  'twitteer',
#  'y',
#  'adios',
#  'justin',
#  "biebeer's",
#  ':)',
#  'felicidades',
#  'a',
#  'mi',
#  'omega,',
#  'el',
#  'mas',
#  'fuerte',
#  'd',
#  'tds',
#  ',',
#  'que',
#  'tienes',
#  'un',
#  'corazón',
#  'enorme.',
#  'te',
#  'echo',
#  'de',
#  'menos',
#  'compi',
#  '.',
#  'cuidate',
#  'mucho.',
#  'te',
#  'quiero',
#  '@nachitopeerez12',
#  '@marixu93',
#  'ooooooooohhhhh',
#  'yo',
#  'tambien',
#  'te',
#  'quiero,',
#  'y',
#  'quiero',
#  'verte',
#  'ya!!!',
#  'guapa!',
#  '@solopuedekedar1',
#  '@kicamqm',
#  '@martafuentesb',
#  'porque',
#  'tan',
#  'abajo',
#  '?',
#  'eso',
#  'no',
#  'puede',
#  'ser',
#  '@jose04011988',
#  '@nereidamarquez6a',
#  'q',
#  'siii',
#  'no',
#  'a',
#  'cambiado',
#  'nadaa',
#  'jajaja',
#  'ea',
#  'tenía',
#  'q',
#  'llover...',
#  '-.-',
#  'qiero',
#  'ver',
#  'a',
#  '@rociomrales17',
#  '@anabelgarcia97',
#  '@paulanadales96',
#  '@laura_pdz97',
#  '@mariagc_97',
#  '@noeliacastro212',
#  '@bonizc',
#  '@pedriitohd17',
#  '@albamartinez_96',
#  '@agusvaras10',
#  'aaah',
#  'buenoo',
#  'esqe',
#  'digo',
#  'pa',
#  'qe',
#  'madrugará',
#  'este',
#  'jajaja',
#  '@sergiomaravish',
#  'jajajaja',
#  'que',
#  'lo',
#  'sepaaas',
#  ';)',
#  'vamos',
#  'al',
#  'lío',
#  'que',
#  'ya',
#  'era',
#  'hora',
#  'de',
#  'empezar!',
#  'ostia',
#  'k',
#  'putada',
#  'yo',
#  'd',
#  'romeria',
#  'to',
#  'la',
#  'noche',
#  'ole',
#  'ole',
#  '@mariadelmar816',
#  'no',
#  'creo',
#  'que',
#  'a',
#  'nadie',
#  'le',
#  'sorprenda',
#  'jajajajaj',
#  'ya',
#  'ves',
#  'que',
#  'ya',
#  'me',
#  'humillo',
#  'yo,',
#  'no',
#  'hace',
#  'falta',
#  'que',
#  'lo',
#  'hagas',
#  'tu',
#  'jajajajaj',
#  ';)',
#  '#meteoalarm',
#  'en',
#  '#granada',
#  'para',
#  'el',
#  '03-04-2013',
#  '01:00:00',
#  'sobre',
#  'viento',
#  'de',
#  'nivel',
#  '#blanco',
#  "i'm",
#  'at',
#  'cercanías',
#  'el',
#  'casar',
#  '-',
#  '@renfe',
#  '(',
#  'getafe',
#  ',',
#  'comunidad',
#  'de',
#  'madrid',
#  ')',
#  'http://t.co/jx1ynjmjex',
#  '#meteoalarm',
#  'en',
#  '#toledo',
#  'para',
#  'el',
#  '01-04-2013',
#  '17:06:00',
#  'sobre',
#  'niebla',
#  'de',
#  'nivel',
#  '#blanco',
#  'ya',
#  'en',
#  'el',
#  'rosal,',
#  'entreno',
#  'con',
#  'el',
#  'b,',
#  'a',
#  'seguir',
#  'currando',
#  '!!',
#  'siento',
#  'mariposas',
#  'en',
#  'el',
#  'estómago..',
#  'creo',
#  'que',
#  'tengo',
#  'de',
#  'dejar',
#  'de',
#  'comerlas.',
#  'y',
#  'decir',
#  'como',
#  'todos',
#  'los',
#  'dias',
#  'a',
#  '@carrasco_111',
#  'que',
#  'hoy',
#  'ha',
#  'sido',
#  'un',
#  'dia',
#  'increíble!,te',
#  'amo!!!!',
#  '@_mariola_',
#  'esq',
#  'veo',
#  'esas',
#  'cosillas',
#  'y',
#  'no',
#  'puedo',
#  'evitar',
#  'pensar',
#  'en',
#  'mi',
#  'media',
#  'naranjilla',
#  'de',
#  'valencia',
#  'jaajja',
#  '@fco_jose96',
#  'me',
#  'encantas,',
#  'lo',
#  'sabes?:$.',
#  'yo',
#  'lo',
#  'he',
#  'intentado',
#  'pero',
#  'no',
#  'recibo',
#  'señales',
#  'dios',
#  'mio',
#  '!',
#  'la',
#  'puerta',
#  'de',
#  'mi',
#  'habitación',
#  'se',
#  'ha',
#  'abierto',
#  'sola!',
#  'estaba',
#  'cerrada',
#  'totalmente!',
#  'que',
#  'yuyu',
#  'xd',
#  'no',
#  'tengo',
#  'sueño',
#  'por',
#  'su',
#  'culpaa',
#  '(::',
#  'y',
#  'esas',
#  'son',
#  'las',
#  'cosas',
#  'que',
#  'se',
#  'me',
#  'vienen',
#  'a',
#  'la',
#  'cabeza',
#  'un',
#  'lunes',
#  'a',
#  'las',
#  '2:05.',
#  'no',
#  'quiero',
#  'entrar',
#  'a',
#  'claseee',
#  ',,,,',
#  'yo',
#  'creo',
#  'que',
#  'por',
#  'hoy',
#  'ya',
#  'vale,',
#  '#buenasnoches',
#  'mi',
#  'sonrisa',
#  'es',
#  'mas',
#  'grande',
#  'que',
#  'mis',
#  'problemas.',
#  'oins',
#  'q',
#  'agustito',
#  'en',
#  'el.#sooufa!',
#  '#twitterosquemecaenbiensinconocer',
#  '@djoytwihard',
#  'porque',
#  'es',
#  'mi',
#  'gemela',
#  '*__*',
#  "'abrir",
#  'la',
#  'ventana,',
#  'colgar',
#  'los',
#  'problemas',
#  'al',
#  "sol'",
#  'a',
#  'descansar',
#  'un',
#  'pokitin',
#  'y',
#  'a',
#  'las',
#  'claseeeesss',
#  'que',
#  'pronto',
#  'se',
#  'acaba',
#  'lo',
#  'bueno!',
#  'buena',
#  '#acampada2013',
#  ':)',
#  '@mace_44',
#  'rojas',
#  'verdes',
#  'y',
#  'amarillas!,',
#  'ami',
#  'me',
#  'gustan',
#  'las',
#  'pastillas!!!!',
#  'jajajajajajaja!,',
#  'que',
#  'de',
#  'risas',
#  'por',
#  'dios!',
#  'xddddd',
#  '@faroleraaaaa',
#  'ojala',
#  'sus',
#  'padres',
#  'les',
#  'enseñen',
#  'en',
#  'casa',
#  'y',
#  'le',
#  'pongan',
#  'eres',
#  'maricon',
#  'en',
#  'la',
#  'nevera',
#  'y',
#  'se',
#  'tengan',
#  'que',
#  'follar',
#  'a',
#  'su',
#  'madre.',
#  '@lluch_miguel',
#  'y',
#  'que',
#  'va',
#  'a',
#  'decir',
#  'su',
#  'madre',
#  'si',
#  'estará',
#  'avergonzada',
#  'de',
#  'tener',
#  'la',
#  'hija',
#  'que',
#  'tiene',
#  'y',
#  'de',
#  'lo',
#  'que',
#  'esta',
#  'haciendo....',
#  '#yanohayboda',
#  '@migueleferndez8',
#  'eres',
#  'inconfundible',
#  'dejando',
#  'espacios',
#  'antes',
#  'de',
#  'los',
#  'signos',
#  'de',
#  'interrogación',
#  'pues',
#  'nada,',
#  'tendre',
#  'que',
#  'moverme.',
#  '@martapellisso',
#  '@mariadelmarg7',
#  'ohhh',
#  'mis',
#  'niñas',
#  'preciosas',
#  'tengo',
#  'muchas',
#  'ganas',
#  'de',
#  'veros',
#  '!!',
#  'os',
#  'quiero♥',
#  '@kurtcomeback_',
#  'si',
#  'te',
#  'llamas',
#  'nacho',
#  'y',
#  'haces',
#  'fotos',
#  'muy',
#  'buenas',
#  'no',
#  'es',
#  'asi',
#  'o',
#  'he',
#  'quedado',
#  'mal?',
#  '@alph4dan',
#  'ay',
#  'gaona',
#  ',',
#  '¡qué',
#  'hombre!',
#  '^^',
#  'todo',
#  'en',
#  'exceso',
#  'es',
#  'malo',
#  'menos',
#  'las',
#  'vacaciones',
#  'k',
#  'mala',
#  'suerte',
#  'coñooo',
#  'se',
#  'me',
#  'a',
#  'roto',
#  'el',
#  'móvil',
#  '@sergiomrqz10',
#  'jajajpero',
#  'esq',
#  'si',
#  'no',
#  'hubiera',
#  'sido',
#  'por',
#  'esa',
#  'preciosa',
#  'llamda',
#  'no',
#  'me',
#  'hubieras',
#  'visto;)',
#  'que',
#  'era',
#  'muy',
#  'tarde',
#  'ya',
#  'jo',
#  'era',
#  'hora',
#  'de',
#  'levantarse',
#  'recuerda',
#  'qur',
#  'lo',
#  'hice',
#  'por',
#  'ti..',
#  'sin',
#  'un',
#  'derroche,',
#  'ni',
#  'un',
#  'gesto',
#  'de',
#  'impaciencia',
#  'ni',
#  'una',
#  'costosa',
#  'recaída',
#  'en',
#  'el',
#  'entusiasmo.',
#  '@marta10mc',
#  '@asundelosreyes',
#  '@mane15amnesia',
#  '@marialguacil97',
#  '@carmen19696',
#  'diiiiiiioooooooo',
#  'jajjajajajajajajajajajajajajajajajajajajajajaja',
#  'me',
#  'levantado',
#  'diciendo',
#  'laura',
#  'hace',
#  'mucho',
#  'sol',
#  'que',
#  'quiero',
#  'ponerme',
#  'morena..',
#  '#markoslibertad',
#  'defender',
#  'a',
#  'nuestro',
#  'pais',
#  'no',
#  'es',
#  'un',
#  'delito',
#  '(+)',
#  'y',
#  'el',
#  'gilipollas',
#  'de',
#  'mourinho',
#  'lo',
#  'único',
#  'que',
#  'está',
#  'haciendo',
#  'es',
#  'destruir',
#  'el',
#  'madridismo',
#  'desde',
#  'dentro.',
#  '@arribassara',
#  '@siilviia_diaz',
#  'cri',
#  'cri,',
#  'yo',
#  'te',
#  'puedo',
#  'con',
#  'un',
#  'dedo',
#  'sara',
#  ':)',
#  'con',
#  'mi',
#  'último',
#  'rt',
#  'dejo',
#  'patente',
#  'que',
#  'es',
#  'imposible',
#  'que',
#  'no',
#  'esté',
#  'enganchada',
#  'a',
#  'twitter',
#  '.',
#  '¡nuestra',
#  'web',
#  'ya',
#  'está',
#  'publicada!',
#  'si',
#  'no',
#  'podéis',
#  'esperar,',
#  'visitad:',
#  'http://t.co/vtajp2sume',
#  'no',
#  'aguanto',
#  'al',
#  'tipico',
#  'sevillano/a',
#  'egocentrico',
#  ',lo',
#  'siento',
#  'asi',
#  'pienso',
#  'y',
#  'he',
#  'pnsao',
#  'to',
#  'mi',
#  'vida',
#  'y',
#  'ojo!mi',
#  'novio',
#  'es',
#  'sevillano',
#  'y',
#  'part',
#  'd',
#  'mis',
#  'amig@s',
#  'tb',
#  '..',
#  '@fernandof_88',
#  '@_lucia4',
#  '@javier_galgero',
#  'ostia',
#  '!!',
#  'sii',
#  '??',
#  'jajajajajajaja',
#  'pues',
#  'yo',
#  'te',
#  'aviso',
#  'primoo',
#  'ajajajjaja',
#  'me',
#  'partoo',
#  ':)',
#  '!!!!',
#  '@bigmartus',
#  'ola',
#  'ker',
#  'lo',
#  'que',
#  'tu',
#  'aseh',
#  '@adrianhill661',
#  'jajajaja',
#  'tssss',
#  '!!!',
#  'si',
#  'dspue',
#  'abandonas!!',
#  '@alfredocalle9',
#  'mis',
#  'pumas',
#  'en',
#  'verano',
#  'metieron',
#  '80',
#  'goles..',
#  'asinque',
#  '..preparate',
#  'para',
#  'no',
#  'moverte..jajajaja',
#  'lo',
#  'mejor',
#  'es',
#  'que',
#  'me',
#  'da',
#  'igual',
#  'todo',
#  'soi',
#  'feliz',
#  'hoy',
#  'a',
#  'algunas',
#  'personas',
#  'les',
#  'daba',
#  'una',
#  'pa',
#  'tada',
#  'en',
#  'la',
#  'boca',
#  'para',
#  'que',
#  'se',
#  'callaran.',
#  'no',
#  'quiero',
#  'dormirme',
#  'pa',
#  'que',
#  'no',
#  'llegue',
#  'mañana....',
#  '#odiandolarutina',
#  'sale',
#  'el',
#  'anuncio',
#  'en',
#  'la',
#  'radio',
#  'del',
#  'centro',
#  'comercial',
#  'de',
#  'la',
#  'zenia',
#  'y',
#  'dicen:',
#  'de',
#  'la',
#  'z',
#  'a',
#  'la',
#  'a.',
#  'y',
#  'dice',
#  'mi',
#  'madre:',
#  'o',
#  'sea',
#  'que',
#  'zara',
#  'sí',
#  'que',
#  'está',
#  'jajajajaja',
#  '@sandraflamencah',
#  '@mariaespinoosa',
#  '@mantoniatenorio',
#  'evidentemente',
#  'q',
#  'para',
#  'gusto...pero',
#  'maría',
#  'es',
#  'artista',
#  'd',
#  'los',
#  'pies',
#  'a',
#  'la',
#  'cabeza,al',
#  'igual',
#  'q',
#  'toñi',
#  '!',
#  'joder',
#  'no',
#  'me',
#  'quito',
#  'la',
#  'lluvia',
#  'macho.',
#  '@marinnyadira',
#  'me',
#  'ha',
#  'faltao',
#  'el',
#  'canto',
#  'un',
#  'duro',
#  'pa',
#  'montar',
#  ...]

# %% [markdown]
# encoder_input_data is a 3D array of shape (num_pairs, max_english_sentence_length, num_english_characters) containing a one-hot vectorization of the English sentences.
#
# decoder_input_data is a 3D array of shape (num_pairs, max_french_sentence_length, num_french_characters) containg a one-hot vectorization of the French sentences.
#
# decoder_target_data is the same as decoder_input_data but offset by one timestep. decoder_target_data[:, t, :] will be the same as decoder_input_data[:, t + 1, :].

# %%
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

# %% [markdown]
# one hot rep

# %%
charb=' '

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[',']] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, (t + 1):, target_token_index[',']] = 1.0
    decoder_target_data[i, t:, target_token_index[',']] = 1.0

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/150
# 90/90 [==============================] - 5s 21ms/step - loss: 0.9632 - accuracy: 0.8140 - val_loss: 0.6330 - val_accuracy: 0.8491
# Epoch 2/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.5654 - accuracy: 0.8576 - val_loss: 0.5423 - val_accuracy: 0.8572
# Epoch 3/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.5094 - accuracy: 0.8697 - val_loss: 0.5073 - val_accuracy: 0.8653
# Epoch 4/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.4761 - accuracy: 0.8762 - val_loss: 0.4738 - val_accuracy: 0.8751
# Epoch 5/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.4447 - accuracy: 0.8816 - val_loss: 0.4467 - val_accuracy: 0.8821
# Epoch 6/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.4144 - accuracy: 0.8872 - val_loss: 0.4116 - val_accuracy: 0.8861
# Epoch 7/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.3932 - accuracy: 0.8905 - val_loss: 0.4057 - val_accuracy: 0.8840
# Epoch 8/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.3771 - accuracy: 0.8940 - val_loss: 0.3811 - val_accuracy: 0.8912
# Epoch 9/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3653 - accuracy: 0.8960 - val_loss: 0.3704 - val_accuracy: 0.8922
# Epoch 10/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3552 - accuracy: 0.8984 - val_loss: 0.3643 - val_accuracy: 0.8948
# Epoch 11/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3458 - accuracy: 0.8998 - val_loss: 0.3565 - val_accuracy: 0.8941
# Epoch 12/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3393 - accuracy: 0.9007 - val_loss: 0.3534 - val_accuracy: 0.8998
# Epoch 13/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3331 - accuracy: 0.9026 - val_loss: 0.3437 - val_accuracy: 0.8975
# Epoch 14/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3271 - accuracy: 0.9035 - val_loss: 0.3360 - val_accuracy: 0.8996
# Epoch 15/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3219 - accuracy: 0.9047 - val_loss: 0.3331 - val_accuracy: 0.9026
# Epoch 16/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.3173 - accuracy: 0.9058 - val_loss: 0.3311 - val_accuracy: 0.9015
# Epoch 17/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.3132 - accuracy: 0.9071 - val_loss: 0.3321 - val_accuracy: 0.9035
# Epoch 18/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.3103 - accuracy: 0.9077 - val_loss: 0.3222 - val_accuracy: 0.9041
# Epoch 19/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.3085 - accuracy: 0.9085 - val_loss: 0.3184 - val_accuracy: 0.9059
# Epoch 20/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.3085 - accuracy: 0.9087 - val_loss: 0.3310 - val_accuracy: 0.9029
# Epoch 21/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.3029 - accuracy: 0.9103 - val_loss: 0.3180 - val_accuracy: 0.9052
# Epoch 22/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.2992 - accuracy: 0.9108 - val_loss: 0.3218 - val_accuracy: 0.9042
# Epoch 23/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.2957 - accuracy: 0.9115 - val_loss: 0.3103 - val_accuracy: 0.9083
# Epoch 24/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.2925 - accuracy: 0.9126 - val_loss: 0.3068 - val_accuracy: 0.9098
# Epoch 25/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.2903 - accuracy: 0.9135 - val_loss: 0.3033 - val_accuracy: 0.9113
# Epoch 26/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.2873 - accuracy: 0.9137 - val_loss: 0.3051 - val_accuracy: 0.9110
# Epoch 27/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2840 - accuracy: 0.9155 - val_loss: 0.3061 - val_accuracy: 0.9094
# Epoch 28/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2803 - accuracy: 0.9162 - val_loss: 0.2977 - val_accuracy: 0.9126
# Epoch 29/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2765 - accuracy: 0.9172 - val_loss: 0.2951 - val_accuracy: 0.9133
# Epoch 30/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2725 - accuracy: 0.9185 - val_loss: 0.2884 - val_accuracy: 0.9173
# Epoch 31/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2691 - accuracy: 0.9202 - val_loss: 0.2882 - val_accuracy: 0.9165
# Epoch 32/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2639 - accuracy: 0.9220 - val_loss: 0.2993 - val_accuracy: 0.9113
# Epoch 33/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2601 - accuracy: 0.9227 - val_loss: 0.2845 - val_accuracy: 0.9165
# Epoch 34/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2564 - accuracy: 0.9239 - val_loss: 0.2795 - val_accuracy: 0.9186
# Epoch 35/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2545 - accuracy: 0.9243 - val_loss: 0.2787 - val_accuracy: 0.9188
# Epoch 36/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.2487 - accuracy: 0.9262 - val_loss: 0.2722 - val_accuracy: 0.9234
# Epoch 37/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.2449 - accuracy: 0.9274 - val_loss: 0.2683 - val_accuracy: 0.9224
# Epoch 38/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2416 - accuracy: 0.9287 - val_loss: 0.2684 - val_accuracy: 0.9241
# Epoch 39/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.2375 - accuracy: 0.9302 - val_loss: 0.2595 - val_accuracy: 0.9258
# Epoch 40/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2327 - accuracy: 0.9321 - val_loss: 0.2548 - val_accuracy: 0.9288
# Epoch 41/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2285 - accuracy: 0.9335 - val_loss: 0.2558 - val_accuracy: 0.9291
# Epoch 42/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2247 - accuracy: 0.9350 - val_loss: 0.2514 - val_accuracy: 0.9307
# Epoch 43/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2204 - accuracy: 0.9369 - val_loss: 0.2526 - val_accuracy: 0.9293
# Epoch 44/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2176 - accuracy: 0.9375 - val_loss: 0.2446 - val_accuracy: 0.9333
# Epoch 45/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2134 - accuracy: 0.9387 - val_loss: 0.2396 - val_accuracy: 0.9341
# Epoch 46/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2091 - accuracy: 0.9402 - val_loss: 0.2323 - val_accuracy: 0.9374
# Epoch 47/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2057 - accuracy: 0.9410 - val_loss: 0.2340 - val_accuracy: 0.9366
# Epoch 48/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2005 - accuracy: 0.9427 - val_loss: 0.2282 - val_accuracy: 0.9389
# Epoch 49/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1977 - accuracy: 0.9436 - val_loss: 0.2304 - val_accuracy: 0.9374
# Epoch 50/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1934 - accuracy: 0.9449 - val_loss: 0.2216 - val_accuracy: 0.9402
# Epoch 51/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1890 - accuracy: 0.9464 - val_loss: 0.2227 - val_accuracy: 0.9402
# Epoch 52/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1856 - accuracy: 0.9474 - val_loss: 0.2212 - val_accuracy: 0.9415
# Epoch 53/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1829 - accuracy: 0.9483 - val_loss: 0.2162 - val_accuracy: 0.9415
# Epoch 54/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1791 - accuracy: 0.9490 - val_loss: 0.2090 - val_accuracy: 0.9438
# Epoch 55/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1749 - accuracy: 0.9506 - val_loss: 0.2040 - val_accuracy: 0.9459
# Epoch 56/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1715 - accuracy: 0.9513 - val_loss: 0.2096 - val_accuracy: 0.9439
# Epoch 57/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1692 - accuracy: 0.9522 - val_loss: 0.1995 - val_accuracy: 0.9467
# Epoch 58/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1664 - accuracy: 0.9530 - val_loss: 0.1938 - val_accuracy: 0.9493
# Epoch 59/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1638 - accuracy: 0.9541 - val_loss: 0.2063 - val_accuracy: 0.9445
# Epoch 60/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1602 - accuracy: 0.9549 - val_loss: 0.1971 - val_accuracy: 0.9472
# Epoch 61/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1578 - accuracy: 0.9556 - val_loss: 0.1960 - val_accuracy: 0.9477
# Epoch 62/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1553 - accuracy: 0.9562 - val_loss: 0.1893 - val_accuracy: 0.9499
# Epoch 63/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1522 - accuracy: 0.9574 - val_loss: 0.1906 - val_accuracy: 0.9497
# Epoch 64/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1505 - accuracy: 0.9579 - val_loss: 0.1938 - val_accuracy: 0.9491
# Epoch 65/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1478 - accuracy: 0.9584 - val_loss: 0.1908 - val_accuracy: 0.9503
# Epoch 66/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1450 - accuracy: 0.9594 - val_loss: 0.1886 - val_accuracy: 0.9505
# Epoch 67/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1426 - accuracy: 0.9603 - val_loss: 0.1832 - val_accuracy: 0.9522
# Epoch 68/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1401 - accuracy: 0.9606 - val_loss: 0.1962 - val_accuracy: 0.9483
# Epoch 69/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1383 - accuracy: 0.9612 - val_loss: 0.1766 - val_accuracy: 0.9539
# Epoch 70/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1364 - accuracy: 0.9617 - val_loss: 0.1767 - val_accuracy: 0.9547
# Epoch 71/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1344 - accuracy: 0.9625 - val_loss: 0.1816 - val_accuracy: 0.9523
# Epoch 72/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1323 - accuracy: 0.9631 - val_loss: 0.1763 - val_accuracy: 0.9543
# Epoch 73/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1300 - accuracy: 0.9637 - val_loss: 0.1745 - val_accuracy: 0.9545
# Epoch 74/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1290 - accuracy: 0.9638 - val_loss: 0.1696 - val_accuracy: 0.9567
# Epoch 75/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1269 - accuracy: 0.9645 - val_loss: 0.1779 - val_accuracy: 0.9553
# Epoch 76/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1264 - accuracy: 0.9651 - val_loss: 0.1761 - val_accuracy: 0.9556
# Epoch 77/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1233 - accuracy: 0.9655 - val_loss: 0.1685 - val_accuracy: 0.9573
# Epoch 78/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1221 - accuracy: 0.9659 - val_loss: 0.1699 - val_accuracy: 0.9575
# Epoch 79/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1224 - accuracy: 0.9659 - val_loss: 0.1685 - val_accuracy: 0.9566
# Epoch 80/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1185 - accuracy: 0.9671 - val_loss: 0.1665 - val_accuracy: 0.9571
# Epoch 81/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1174 - accuracy: 0.9673 - val_loss: 0.1604 - val_accuracy: 0.9598
# Epoch 82/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1150 - accuracy: 0.9678 - val_loss: 0.1713 - val_accuracy: 0.9561
# Epoch 83/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1152 - accuracy: 0.9681 - val_loss: 0.1678 - val_accuracy: 0.9566
# Epoch 84/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1122 - accuracy: 0.9686 - val_loss: 0.1631 - val_accuracy: 0.9587
# Epoch 85/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1111 - accuracy: 0.9690 - val_loss: 0.1610 - val_accuracy: 0.9598
# Epoch 86/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1089 - accuracy: 0.9699 - val_loss: 0.1674 - val_accuracy: 0.9583
# Epoch 87/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1080 - accuracy: 0.9699 - val_loss: 0.1597 - val_accuracy: 0.9606
# Epoch 88/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1064 - accuracy: 0.9705 - val_loss: 0.1703 - val_accuracy: 0.9565
# Epoch 89/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1049 - accuracy: 0.9707 - val_loss: 0.1665 - val_accuracy: 0.9579
# Epoch 90/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1036 - accuracy: 0.9712 - val_loss: 0.1624 - val_accuracy: 0.9598
# Epoch 91/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1027 - accuracy: 0.9713 - val_loss: 0.1597 - val_accuracy: 0.9611
# Epoch 92/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1009 - accuracy: 0.9719 - val_loss: 0.1566 - val_accuracy: 0.9622
# Epoch 93/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1009 - accuracy: 0.9723 - val_loss: 0.1579 - val_accuracy: 0.9610
# Epoch 94/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0993 - accuracy: 0.9726 - val_loss: 0.1569 - val_accuracy: 0.9617
# Epoch 95/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0978 - accuracy: 0.9728 - val_loss: 0.1543 - val_accuracy: 0.9623
# Epoch 96/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0968 - accuracy: 0.9733 - val_loss: 0.1568 - val_accuracy: 0.9617
# Epoch 97/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0951 - accuracy: 0.9735 - val_loss: 0.1665 - val_accuracy: 0.9590
# Epoch 98/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0937 - accuracy: 0.9739 - val_loss: 0.1605 - val_accuracy: 0.9611
# Epoch 99/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0936 - accuracy: 0.9740 - val_loss: 0.1703 - val_accuracy: 0.9590
# Epoch 100/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0925 - accuracy: 0.9745 - val_loss: 0.1562 - val_accuracy: 0.9616
# Epoch 101/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0911 - accuracy: 0.9747 - val_loss: 0.1579 - val_accuracy: 0.9618
# Epoch 102/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0891 - accuracy: 0.9754 - val_loss: 0.1538 - val_accuracy: 0.9626
# Epoch 103/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0890 - accuracy: 0.9754 - val_loss: 0.1639 - val_accuracy: 0.9596
# Epoch 104/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0883 - accuracy: 0.9758 - val_loss: 0.1505 - val_accuracy: 0.9639
# Epoch 105/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0869 - accuracy: 0.9760 - val_loss: 0.1552 - val_accuracy: 0.9626
# Epoch 106/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0864 - accuracy: 0.9761 - val_loss: 0.1488 - val_accuracy: 0.9640
# Epoch 107/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0843 - accuracy: 0.9768 - val_loss: 0.1514 - val_accuracy: 0.9641
# Epoch 108/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0832 - accuracy: 0.9772 - val_loss: 0.1523 - val_accuracy: 0.9637
# Epoch 109/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0831 - accuracy: 0.9768 - val_loss: 0.1536 - val_accuracy: 0.9633
# Epoch 110/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0818 - accuracy: 0.9773 - val_loss: 0.1618 - val_accuracy: 0.9620
# Epoch 111/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0802 - accuracy: 0.9778 - val_loss: 0.1540 - val_accuracy: 0.9635
# Epoch 112/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0797 - accuracy: 0.9779 - val_loss: 0.1596 - val_accuracy: 0.9624
# Epoch 113/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0768 - accuracy: 0.9792 - val_loss: 0.1527 - val_accuracy: 0.9644
# Epoch 114/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0784 - accuracy: 0.9783 - val_loss: 0.1506 - val_accuracy: 0.9644
# Epoch 115/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0774 - accuracy: 0.9785 - val_loss: 0.1624 - val_accuracy: 0.9621
# Epoch 116/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0766 - accuracy: 0.9788 - val_loss: 0.1486 - val_accuracy: 0.9657
# Epoch 117/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0755 - accuracy: 0.9791 - val_loss: 0.1515 - val_accuracy: 0.9650
# Epoch 118/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0745 - accuracy: 0.9792 - val_loss: 0.1534 - val_accuracy: 0.9652
# Epoch 119/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0739 - accuracy: 0.9795 - val_loss: 0.1561 - val_accuracy: 0.9643
# Epoch 120/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0734 - accuracy: 0.9796 - val_loss: 0.1492 - val_accuracy: 0.9655
# Epoch 121/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0722 - accuracy: 0.9800 - val_loss: 0.1565 - val_accuracy: 0.9639
# Epoch 122/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0720 - accuracy: 0.9797 - val_loss: 0.1532 - val_accuracy: 0.9647
# Epoch 123/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0709 - accuracy: 0.9805 - val_loss: 0.1667 - val_accuracy: 0.9622
# Epoch 124/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0705 - accuracy: 0.9804 - val_loss: 0.1566 - val_accuracy: 0.9644
# Epoch 125/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0688 - accuracy: 0.9812 - val_loss: 0.1565 - val_accuracy: 0.9642
# Epoch 126/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0681 - accuracy: 0.9812 - val_loss: 0.1547 - val_accuracy: 0.9647
# Epoch 127/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0678 - accuracy: 0.9813 - val_loss: 0.1518 - val_accuracy: 0.9655
# Epoch 128/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0676 - accuracy: 0.9812 - val_loss: 0.1518 - val_accuracy: 0.9659
# Epoch 129/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0659 - accuracy: 0.9817 - val_loss: 0.1527 - val_accuracy: 0.9654
# Epoch 130/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0651 - accuracy: 0.9821 - val_loss: 0.1602 - val_accuracy: 0.9646
# Epoch 131/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0650 - accuracy: 0.9820 - val_loss: 0.1520 - val_accuracy: 0.9662
# Epoch 132/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0643 - accuracy: 0.9822 - val_loss: 0.1559 - val_accuracy: 0.9649
# Epoch 133/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0635 - accuracy: 0.9824 - val_loss: 0.1556 - val_accuracy: 0.9652
# Epoch 134/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0633 - accuracy: 0.9823 - val_loss: 0.1696 - val_accuracy: 0.9622
# Epoch 135/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0640 - accuracy: 0.9825 - val_loss: 0.1583 - val_accuracy: 0.9653
# Epoch 136/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0630 - accuracy: 0.9828 - val_loss: 0.1657 - val_accuracy: 0.9633
# Epoch 137/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0627 - accuracy: 0.9828 - val_loss: 0.1614 - val_accuracy: 0.9645
# Epoch 138/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0614 - accuracy: 0.9831 - val_loss: 0.1551 - val_accuracy: 0.9664
# Epoch 139/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0605 - accuracy: 0.9833 - val_loss: 0.1577 - val_accuracy: 0.9653
# Epoch 140/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0594 - accuracy: 0.9834 - val_loss: 0.1560 - val_accuracy: 0.9662
# Epoch 141/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0585 - accuracy: 0.9838 - val_loss: 0.1596 - val_accuracy: 0.9650
# Epoch 142/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0579 - accuracy: 0.9840 - val_loss: 0.1542 - val_accuracy: 0.9667
# Epoch 143/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0580 - accuracy: 0.9838 - val_loss: 0.1591 - val_accuracy: 0.9654
# Epoch 144/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0564 - accuracy: 0.9844 - val_loss: 0.1580 - val_accuracy: 0.9662
# Epoch 145/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0560 - accuracy: 0.9846 - val_loss: 0.1544 - val_accuracy: 0.9664
# Epoch 146/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0557 - accuracy: 0.9846 - val_loss: 0.1577 - val_accuracy: 0.9659
# Epoch 147/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0557 - accuracy: 0.9846 - val_loss: 0.1564 - val_accuracy: 0.9661
# Epoch 148/150
# 90/90 [==============================] - 1s 13ms/step - loss: 0.0548 - accuracy: 0.9850 - val_loss: 0.1774 - val_accuracy: 0.9615
# Epoch 149/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0541 - accuracy: 0.9853 - val_loss: 0.1603 - val_accuracy: 0.9657
# Epoch 150/150
# 90/90 [==============================] - 1s 12ms/step - loss: 0.0533 - accuracy: 0.9853 - val_loss: 0.1619 - val_accuracy: 0.9654
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_2_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2s/assets
# INFO:tensorflow:Assets written to: s2s/assets

# %%
from tensorflow.keras.utils import plot_model
plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)

# %% [markdown]
# testing with validation

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,), name="input_6")
decoder_state_input_c = keras.Input(shape=(latent_dim,), name="input_5")
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(50):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: la
# Decoded sentence: la
#
# -
# Input sentence: gente
# Decoded sentence: gente
#
# -
# Input sentence: no
# Decoded sentence: no
#
# -
# Input sentence: cambia
# Decoded sentence: cambia
#
# -
# Input sentence: por
# Decoded sentence: por
#
# -
# Input sentence: que
# Decoded sentence: que
#
# -
# Input sentence: quiere,
# Decoded sentence: quiere
#
# -
# Input sentence: sino
# Decoded sentence: sino
#
# -
# Input sentence: por
# Decoded sentence: por
#
# -
# Input sentence: que
# Decoded sentence: que
#
# -
# Input sentence: le
# Decoded sentence: le
#
# -
# Input sentence: hicieron
# Decoded sentence: hicherio
#
# -
# Input sentence: daño
# Decoded sentence: daño
#
# -
# Input sentence: y
# Decoded sentence: y
#
# -
# Input sentence: se
# Decoded sentence: se
#
# -
# Input sentence: vio
# Decoded sentence: vio
#
# -
# Input sentence: obligada
# Decoded sentence: bocrías.
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: dejar
# Decoded sentence: dejar
#
# -
# Input sentence: de
# Decoded sentence: de
#
# -
# Input sentence: ser
# Decoded sentence: ser
#
# -
# Input sentence: quien
# Decoded sentence: quien
#
# -
# Input sentence: era
# Decoded sentence: era
#
# -
# Input sentence: ..
# Decoded sentence: ..
#
# -
# Input sentence: hoy
# Decoded sentence: hoy
#
# -
# Input sentence: llevo
# Decoded sentence: llevo
#
# -
# Input sentence: la
# Decoded sentence: la
#
# -
# Input sentence: camiseta
# Decoded sentence: camisiar
#
# -
# Input sentence: de
# Decoded sentence: de
#
# -
# Input sentence: batman
# Decoded sentence: batpame
#
# -
# Input sentence: jdjejdkahflwkdjwpvqh
# Decoded sentence: jdjejjodelturalkez96
#
# -
# Input sentence: .
# Decoded sentence: .
#
# -
# Input sentence: el
# Decoded sentence: el
#
# -
# Input sentence: siestón
# Decoded sentence: siestora
#
# -
# Input sentence: que
# Decoded sentence: que
#
# -
# Input sentence: me
# Decoded sentence: me
#
# -
# Input sentence: voy
# Decoded sentence: voy
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: echar
# Decoded sentence: echar
#
# -
# Input sentence: hoy
# Decoded sentence: hoy
#
# -
# Input sentence: va
# Decoded sentence: va
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: ser
# Decoded sentence: ser
#
# -
# Input sentence: digno...!
# Decoded sentence: digno...!
#
# -
# Input sentence: @xheartbreaker_
# Decoded sentence: @blincandell
#
# -
# Input sentence: ay
# Decoded sentence: ay
#
# -
# Input sentence: dios,
# Decoded sentence: dios
#
# -
# Input sentence: hoy
# Decoded sentence: hoy
#
# -
# Input sentence: acabo
# Decoded sentence: acabo
#
# -
# Input sentence: en
# Decoded sentence: en
