# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyab1111/MultiLexNorm-Challenge/blob/main/Spanish/es_ln_seq2seq_biLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Embedding, Concatenate
from tensorflow.keras import Input, Model

# %% [markdown]
# Espaniol

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 128  # Latent dimensionality of the encoding space.
num_samples = 30000  # Number of samples to train on.
data_path = '/content/drive/MyDrive/NLP/Lexical Normalisation/Multilexnorm Challenge/Spanish/es.train.norm.txt'

# %% [markdown]
# Character encoding

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r") as f:
    lines = f.readlines()
for line in lines[: min(num_samples, len(lines) - 1)]:
  if line=='\n':
    continue
  else:
    input_text, target_text= line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)
# Out:
# Number of samples: 7189
# Number of unique input tokens: 80
# Number of unique output tokens: 80
# Max sequence length for inputs: 47
# Max sequence length for outputs: 36

# %%
input_texts
# Out:
# ['la',
#  'gente',
#  'no',
#  'cambia',
#  'por',
#  'que',
#  'quiere,',
#  'sino',
#  'por',
#  'que',
#  'le',
#  'hicieron',
#  'daño',
#  'y',
#  'se',
#  'vio',
#  'obligada',
#  'a',
#  'dejar',
#  'de',
#  'ser',
#  'quien',
#  'era',
#  '..',
#  'hoy',
#  'llevo',
#  'la',
#  'camiseta',
#  'de',
#  'batman',
#  'jdjejdkahflwkdjwpvqh',
#  '.',
#  'el',
#  'siestón',
#  'que',
#  'me',
#  'voy',
#  'a',
#  'echar',
#  'hoy',
#  'va',
#  'a',
#  'ser',
#  'digno...!',
#  '@xheartbreaker_',
#  'ay',
#  'dios,',
#  'hoy',
#  'acabo',
#  'en',
#  'el',
#  'hospital',
#  'por',
#  'ataques.',
#  'esperando',
#  'walking',
#  'dead',
#  '.',
#  'a',
#  'ver',
#  'como',
#  'acaba...',
#  '@ursulaa5',
#  'me',
#  'esquivocao',
#  'y',
#  'estoy',
#  'en',
#  'el',
#  'donald',
#  'del',
#  'piolin',
#  'ya',
#  'estoy',
#  'yendo.',
#  'http://t.co/q9kq4daxfv',
#  '@cristinasorisa',
#  '@lorenahl16',
#  '@rocioortiz954',
#  '@pilar_2212',
#  '@silvia_sg_95',
#  'de',
#  'paluegos',
#  'del',
#  'fanegol',
#  'jajajajajajajajajjajajajajajaja',
#  'me',
#  'meoooo',
#  '*',
#  'vega',
#  'del',
#  'codorno',
#  '*',
#  'actualizado:',
#  '02-04-2013',
#  '05:02',
#  'utc',
#  '*',
#  'temperatura:',
#  '2,1',
#  'ºc',
#  '(',
#  'máx.',
#  ':',
#  '2,8',
#  '/',
#  'mín.',
#  ':',
#  '2,1',
#  ')',
#  '*',
#  'humedad:...',
#  'http://t.co/yvq0k7mws4',
#  '@loresinte',
#  '@rubitamalaguita',
#  '@bea_diamonds',
#  'miedo',
#  'me',
#  'da',
#  'chicas!!',
#  'miedo',
#  'me',
#  'da',
#  'xq',
#  'el',
#  'año',
#  'pasao',
#  'acabamos',
#  'to',
#  'jamas',
#  'porai',
#  'jajaja',
#  '@danisantostv',
#  'a',
#  'mi',
#  'sobre',
#  'todo',
#  'la',
#  'reacción',
#  'de',
#  'miriam',
#  '#noentiendonada',
#  '#miriampasucasa',
#  '#gh14',
#  '@amaya_fitness',
#  'y',
#  'q',
#  'es',
#  'mejor,',
#  'lentas',
#  'o',
#  'rapidas',
#  'las',
#  'repeticiones?',
#  'no',
#  'se',
#  'que',
#  'responderte!',
#  '..',
#  'ok?',
#  'suena',
#  'borde,',
#  'vale?',
#  'tambien',
#  'suena',
#  'borde,',
#  'gracias?',
#  'no',
#  'lo',
#  'merece,',
#  'que',
#  'te',
#  'digo?..',
#  'pues',
#  'mejor',
#  'me',
#  'callo',
#  'y',
#  'fin.',
#  '#lavidaesmásfácilcuando',
#  'te',
#  'has',
#  'fumado',
#  'unos',
#  'porros,',
#  'no',
#  'hay',
#  'problemas',
#  'ni',
#  'preocupaciones.',
#  'voy',
#  'aaa',
#  'seguir',
#  'el',
#  'camino',
#  'con',
#  'el',
#  'mooovil',
#  'apagado',
#  'que',
#  'caasi',
#  'no',
#  'tengo',
#  'bateriaa',
#  '.',
#  'adioos',
#  'twitteer',
#  'y',
#  'adios',
#  'justin',
#  "biebeer's",
#  ':)',
#  'felicidades',
#  'a',
#  'mi',
#  'omega,',
#  'el',
#  'mas',
#  'fuerte',
#  'd',
#  'tds',
#  ',',
#  'que',
#  'tienes',
#  'un',
#  'corazón',
#  'enorme.',
#  'te',
#  'echo',
#  'de',
#  'menos',
#  'compi',
#  '.',
#  'cuidate',
#  'mucho.',
#  'te',
#  'quiero',
#  '@nachitopeerez12',
#  '@marixu93',
#  'ooooooooohhhhh',
#  'yo',
#  'tambien',
#  'te',
#  'quiero,',
#  'y',
#  'quiero',
#  'verte',
#  'ya!!!',
#  'guapa!',
#  '@solopuedekedar1',
#  '@kicamqm',
#  '@martafuentesb',
#  'porque',
#  'tan',
#  'abajo',
#  '?',
#  'eso',
#  'no',
#  'puede',
#  'ser',
#  '@jose04011988',
#  '@nereidamarquez6a',
#  'q',
#  'siii',
#  'no',
#  'a',
#  'cambiado',
#  'nadaa',
#  'jajaja',
#  'ea',
#  'tenía',
#  'q',
#  'llover...',
#  '-.-',
#  'qiero',
#  'ver',
#  'a',
#  '@rociomrales17',
#  '@anabelgarcia97',
#  '@paulanadales96',
#  '@laura_pdz97',
#  '@mariagc_97',
#  '@noeliacastro212',
#  '@bonizc',
#  '@pedriitohd17',
#  '@albamartinez_96',
#  '@agusvaras10',
#  'aaah',
#  'buenoo',
#  'esqe',
#  'digo',
#  'pa',
#  'qe',
#  'madrugará',
#  'este',
#  'jajaja',
#  '@sergiomaravish',
#  'jajajaja',
#  'que',
#  'lo',
#  'sepaaas',
#  ';)',
#  'vamos',
#  'al',
#  'lío',
#  'que',
#  'ya',
#  'era',
#  'hora',
#  'de',
#  'empezar!',
#  'ostia',
#  'k',
#  'putada',
#  'yo',
#  'd',
#  'romeria',
#  'to',
#  'la',
#  'noche',
#  'ole',
#  'ole',
#  '@mariadelmar816',
#  'no',
#  'creo',
#  'que',
#  'a',
#  'nadie',
#  'le',
#  'sorprenda',
#  'jajajajaj',
#  'ya',
#  'ves',
#  'que',
#  'ya',
#  'me',
#  'humillo',
#  'yo,',
#  'no',
#  'hace',
#  'falta',
#  'que',
#  'lo',
#  'hagas',
#  'tu',
#  'jajajajaj',
#  ';)',
#  '#meteoalarm',
#  'en',
#  '#granada',
#  'para',
#  'el',
#  '03-04-2013',
#  '01:00:00',
#  'sobre',
#  'viento',
#  'de',
#  'nivel',
#  '#blanco',
#  "i'm",
#  'at',
#  'cercanías',
#  'el',
#  'casar',
#  '-',
#  '@renfe',
#  '(',
#  'getafe',
#  ',',
#  'comunidad',
#  'de',
#  'madrid',
#  ')',
#  'http://t.co/jx1ynjmjex',
#  '#meteoalarm',
#  'en',
#  '#toledo',
#  'para',
#  'el',
#  '01-04-2013',
#  '17:06:00',
#  'sobre',
#  'niebla',
#  'de',
#  'nivel',
#  '#blanco',
#  'ya',
#  'en',
#  'el',
#  'rosal,',
#  'entreno',
#  'con',
#  'el',
#  'b,',
#  'a',
#  'seguir',
#  'currando',
#  '!!',
#  'siento',
#  'mariposas',
#  'en',
#  'el',
#  'estómago..',
#  'creo',
#  'que',
#  'tengo',
#  'de',
#  'dejar',
#  'de',
#  'comerlas.',
#  'y',
#  'decir',
#  'como',
#  'todos',
#  'los',
#  'dias',
#  'a',
#  '@carrasco_111',
#  'que',
#  'hoy',
#  'ha',
#  'sido',
#  'un',
#  'dia',
#  'increíble!,te',
#  'amo!!!!',
#  '@_mariola_',
#  'esq',
#  'veo',
#  'esas',
#  'cosillas',
#  'y',
#  'no',
#  'puedo',
#  'evitar',
#  'pensar',
#  'en',
#  'mi',
#  'media',
#  'naranjilla',
#  'de',
#  'valencia',
#  'jaajja',
#  '@fco_jose96',
#  'me',
#  'encantas,',
#  'lo',
#  'sabes?:$.',
#  'yo',
#  'lo',
#  'he',
#  'intentado',
#  'pero',
#  'no',
#  'recibo',
#  'señales',
#  'dios',
#  'mio',
#  '!',
#  'la',
#  'puerta',
#  'de',
#  'mi',
#  'habitación',
#  'se',
#  'ha',
#  'abierto',
#  'sola!',
#  'estaba',
#  'cerrada',
#  'totalmente!',
#  'que',
#  'yuyu',
#  'xd',
#  'no',
#  'tengo',
#  'sueño',
#  'por',
#  'su',
#  'culpaa',
#  '(::',
#  'y',
#  'esas',
#  'son',
#  'las',
#  'cosas',
#  'que',
#  'se',
#  'me',
#  'vienen',
#  'a',
#  'la',
#  'cabeza',
#  'un',
#  'lunes',
#  'a',
#  'las',
#  '2:05.',
#  'no',
#  'quiero',
#  'entrar',
#  'a',
#  'claseee',
#  ',,,,',
#  'yo',
#  'creo',
#  'que',
#  'por',
#  'hoy',
#  'ya',
#  'vale,',
#  '#buenasnoches',
#  'mi',
#  'sonrisa',
#  'es',
#  'mas',
#  'grande',
#  'que',
#  'mis',
#  'problemas.',
#  'oins',
#  'q',
#  'agustito',
#  'en',
#  'el.#sooufa!',
#  '#twitterosquemecaenbiensinconocer',
#  '@djoytwihard',
#  'porque',
#  'es',
#  'mi',
#  'gemela',
#  '*__*',
#  "'abrir",
#  'la',
#  'ventana,',
#  'colgar',
#  'los',
#  'problemas',
#  'al',
#  "sol'",
#  'a',
#  'descansar',
#  'un',
#  'pokitin',
#  'y',
#  'a',
#  'las',
#  'claseeeesss',
#  'que',
#  'pronto',
#  'se',
#  'acaba',
#  'lo',
#  'bueno!',
#  'buena',
#  '#acampada2013',
#  ':)',
#  '@mace_44',
#  'rojas',
#  'verdes',
#  'y',
#  'amarillas!,',
#  'ami',
#  'me',
#  'gustan',
#  'las',
#  'pastillas!!!!',
#  'jajajajajajaja!,',
#  'que',
#  'de',
#  'risas',
#  'por',
#  'dios!',
#  'xddddd',
#  '@faroleraaaaa',
#  'ojala',
#  'sus',
#  'padres',
#  'les',
#  'enseñen',
#  'en',
#  'casa',
#  'y',
#  'le',
#  'pongan',
#  'eres',
#  'maricon',
#  'en',
#  'la',
#  'nevera',
#  'y',
#  'se',
#  'tengan',
#  'que',
#  'follar',
#  'a',
#  'su',
#  'madre.',
#  '@lluch_miguel',
#  'y',
#  'que',
#  'va',
#  'a',
#  'decir',
#  'su',
#  'madre',
#  'si',
#  'estará',
#  'avergonzada',
#  'de',
#  'tener',
#  'la',
#  'hija',
#  'que',
#  'tiene',
#  'y',
#  'de',
#  'lo',
#  'que',
#  'esta',
#  'haciendo....',
#  '#yanohayboda',
#  '@migueleferndez8',
#  'eres',
#  'inconfundible',
#  'dejando',
#  'espacios',
#  'antes',
#  'de',
#  'los',
#  'signos',
#  'de',
#  'interrogación',
#  'pues',
#  'nada,',
#  'tendre',
#  'que',
#  'moverme.',
#  '@martapellisso',
#  '@mariadelmarg7',
#  'ohhh',
#  'mis',
#  'niñas',
#  'preciosas',
#  'tengo',
#  'muchas',
#  'ganas',
#  'de',
#  'veros',
#  '!!',
#  'os',
#  'quiero♥',
#  '@kurtcomeback_',
#  'si',
#  'te',
#  'llamas',
#  'nacho',
#  'y',
#  'haces',
#  'fotos',
#  'muy',
#  'buenas',
#  'no',
#  'es',
#  'asi',
#  'o',
#  'he',
#  'quedado',
#  'mal?',
#  '@alph4dan',
#  'ay',
#  'gaona',
#  ',',
#  '¡qué',
#  'hombre!',
#  '^^',
#  'todo',
#  'en',
#  'exceso',
#  'es',
#  'malo',
#  'menos',
#  'las',
#  'vacaciones',
#  'k',
#  'mala',
#  'suerte',
#  'coñooo',
#  'se',
#  'me',
#  'a',
#  'roto',
#  'el',
#  'móvil',
#  '@sergiomrqz10',
#  'jajajpero',
#  'esq',
#  'si',
#  'no',
#  'hubiera',
#  'sido',
#  'por',
#  'esa',
#  'preciosa',
#  'llamda',
#  'no',
#  'me',
#  'hubieras',
#  'visto;)',
#  'que',
#  'era',
#  'muy',
#  'tarde',
#  'ya',
#  'jo',
#  'era',
#  'hora',
#  'de',
#  'levantarse',
#  'recuerda',
#  'qur',
#  'lo',
#  'hice',
#  'por',
#  'ti..',
#  'sin',
#  'un',
#  'derroche,',
#  'ni',
#  'un',
#  'gesto',
#  'de',
#  'impaciencia',
#  'ni',
#  'una',
#  'costosa',
#  'recaída',
#  'en',
#  'el',
#  'entusiasmo.',
#  '@marta10mc',
#  '@asundelosreyes',
#  '@mane15amnesia',
#  '@marialguacil97',
#  '@carmen19696',
#  'diiiiiiioooooooo',
#  'jajjajajajajajajajajajajajajajajajajajajajajaja',
#  'me',
#  'levantado',
#  'diciendo',
#  'laura',
#  'hace',
#  'mucho',
#  'sol',
#  'que',
#  'quiero',
#  'ponerme',
#  'morena..',
#  '#markoslibertad',
#  'defender',
#  'a',
#  'nuestro',
#  'pais',
#  'no',
#  'es',
#  'un',
#  'delito',
#  '(+)',
#  'y',
#  'el',
#  'gilipollas',
#  'de',
#  'mourinho',
#  'lo',
#  'único',
#  'que',
#  'está',
#  'haciendo',
#  'es',
#  'destruir',
#  'el',
#  'madridismo',
#  'desde',
#  'dentro.',
#  '@arribassara',
#  '@siilviia_diaz',
#  'cri',
#  'cri,',
#  'yo',
#  'te',
#  'puedo',
#  'con',
#  'un',
#  'dedo',
#  'sara',
#  ':)',
#  'con',
#  'mi',
#  'último',
#  'rt',
#  'dejo',
#  'patente',
#  'que',
#  'es',
#  'imposible',
#  'que',
#  'no',
#  'esté',
#  'enganchada',
#  'a',
#  'twitter',
#  '.',
#  '¡nuestra',
#  'web',
#  'ya',
#  'está',
#  'publicada!',
#  'si',
#  'no',
#  'podéis',
#  'esperar,',
#  'visitad:',
#  'http://t.co/vtajp2sume',
#  'no',
#  'aguanto',
#  'al',
#  'tipico',
#  'sevillano/a',
#  'egocentrico',
#  ',lo',
#  'siento',
#  'asi',
#  'pienso',
#  'y',
#  'he',
#  'pnsao',
#  'to',
#  'mi',
#  'vida',
#  'y',
#  'ojo!mi',
#  'novio',
#  'es',
#  'sevillano',
#  'y',
#  'part',
#  'd',
#  'mis',
#  'amig@s',
#  'tb',
#  '..',
#  '@fernandof_88',
#  '@_lucia4',
#  '@javier_galgero',
#  'ostia',
#  '!!',
#  'sii',
#  '??',
#  'jajajajajajaja',
#  'pues',
#  'yo',
#  'te',
#  'aviso',
#  'primoo',
#  'ajajajjaja',
#  'me',
#  'partoo',
#  ':)',
#  '!!!!',
#  '@bigmartus',
#  'ola',
#  'ker',
#  'lo',
#  'que',
#  'tu',
#  'aseh',
#  '@adrianhill661',
#  'jajajaja',
#  'tssss',
#  '!!!',
#  'si',
#  'dspue',
#  'abandonas!!',
#  '@alfredocalle9',
#  'mis',
#  'pumas',
#  'en',
#  'verano',
#  'metieron',
#  '80',
#  'goles..',
#  'asinque',
#  '..preparate',
#  'para',
#  'no',
#  'moverte..jajajaja',
#  'lo',
#  'mejor',
#  'es',
#  'que',
#  'me',
#  'da',
#  'igual',
#  'todo',
#  'soi',
#  'feliz',
#  'hoy',
#  'a',
#  'algunas',
#  'personas',
#  'les',
#  'daba',
#  'una',
#  'pa',
#  'tada',
#  'en',
#  'la',
#  'boca',
#  'para',
#  'que',
#  'se',
#  'callaran.',
#  'no',
#  'quiero',
#  'dormirme',
#  'pa',
#  'que',
#  'no',
#  'llegue',
#  'mañana....',
#  '#odiandolarutina',
#  'sale',
#  'el',
#  'anuncio',
#  'en',
#  'la',
#  'radio',
#  'del',
#  'centro',
#  'comercial',
#  'de',
#  'la',
#  'zenia',
#  'y',
#  'dicen:',
#  'de',
#  'la',
#  'z',
#  'a',
#  'la',
#  'a.',
#  'y',
#  'dice',
#  'mi',
#  'madre:',
#  'o',
#  'sea',
#  'que',
#  'zara',
#  'sí',
#  'que',
#  'está',
#  'jajajajaja',
#  '@sandraflamencah',
#  '@mariaespinoosa',
#  '@mantoniatenorio',
#  'evidentemente',
#  'q',
#  'para',
#  'gusto...pero',
#  'maría',
#  'es',
#  'artista',
#  'd',
#  'los',
#  'pies',
#  'a',
#  'la',
#  'cabeza,al',
#  'igual',
#  'q',
#  'toñi',
#  '!',
#  'joder',
#  'no',
#  'me',
#  'quito',
#  'la',
#  'lluvia',
#  'macho.',
#  '@marinnyadira',
#  'me',
#  'ha',
#  'faltao',
#  'el',
#  'canto',
#  'un',
#  'duro',
#  'pa',
#  'montar',
#  ...]

# %% [markdown]
# encoder_input_data is a 3D array of shape (num_pairs, max_english_sentence_length, num_english_characters) containing a one-hot vectorization of the English sentences.
#
# decoder_input_data is a 3D array of shape (num_pairs, max_french_sentence_length, num_french_characters) containg a one-hot vectorization of the French sentences.
#
# decoder_target_data is the same as decoder_input_data but offset by one timestep. decoder_target_data[:, t, :] will be the same as decoder_input_data[:, t + 1, :].

# %%
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

# %% [markdown]
# one hot rep

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[',']] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, (t + 1):, target_token_index[',']] = 1.0
    decoder_target_data[i, t:, target_token_index[',']] = 1.0

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = Bidirectional(LSTM(latent_dim, return_state=True, return_sequences=True))
encoder_outputs1, forw_state_h, forw_state_c, back_state_h, back_state_c = encoder(encoder_inputs)

state_h = Concatenate()([forw_state_h, back_state_h])
state_c = Concatenate()([forw_state_c, back_state_c])

encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM((2*latent_dim), return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 90/90 [==============================] - 15s 65ms/step - loss: 0.7519 - accuracy: 0.8296 - val_loss: 0.5424 - val_accuracy: 0.8568
# Epoch 2/100
# 90/90 [==============================] - 4s 49ms/step - loss: 0.4935 - accuracy: 0.8657 - val_loss: 0.4632 - val_accuracy: 0.8699
# Epoch 3/100
# 90/90 [==============================] - 4s 49ms/step - loss: 0.4268 - accuracy: 0.8843 - val_loss: 0.3913 - val_accuracy: 0.9059
# Epoch 4/100
# 90/90 [==============================] - 4s 47ms/step - loss: 0.3464 - accuracy: 0.9101 - val_loss: 0.3135 - val_accuracy: 0.9200
# Epoch 5/100
# 90/90 [==============================] - 4s 48ms/step - loss: 0.2760 - accuracy: 0.9290 - val_loss: 0.5564 - val_accuracy: 0.9146
# Epoch 6/100
# 90/90 [==============================] - 4s 48ms/step - loss: 0.2284 - accuracy: 0.9405 - val_loss: 0.2076 - val_accuracy: 0.9459
# Epoch 7/100
# 90/90 [==============================] - 4s 47ms/step - loss: 0.1888 - accuracy: 0.9499 - val_loss: 0.1835 - val_accuracy: 0.9510
# Epoch 8/100
# 90/90 [==============================] - 4s 47ms/step - loss: 0.1546 - accuracy: 0.9588 - val_loss: 0.1419 - val_accuracy: 0.9633
# Epoch 9/100
# 90/90 [==============================] - 4s 47ms/step - loss: 0.1286 - accuracy: 0.9665 - val_loss: 0.1364 - val_accuracy: 0.9639
# Epoch 10/100
# 90/90 [==============================] - 4s 46ms/step - loss: 0.1098 - accuracy: 0.9712 - val_loss: 0.1137 - val_accuracy: 0.9708
# Epoch 11/100
# 90/90 [==============================] - 4s 47ms/step - loss: 0.0958 - accuracy: 0.9747 - val_loss: 0.1043 - val_accuracy: 0.9735
# Epoch 12/100
# 90/90 [==============================] - 4s 47ms/step - loss: 0.0842 - accuracy: 0.9780 - val_loss: 0.0985 - val_accuracy: 0.9742
# Epoch 13/100
# 90/90 [==============================] - 4s 46ms/step - loss: 0.0747 - accuracy: 0.9805 - val_loss: 0.0915 - val_accuracy: 0.9757
# Epoch 14/100
# 90/90 [==============================] - 4s 45ms/step - loss: 0.0670 - accuracy: 0.9824 - val_loss: 0.0849 - val_accuracy: 0.9791
# Epoch 15/100
# 90/90 [==============================] - 4s 45ms/step - loss: 0.0608 - accuracy: 0.9841 - val_loss: 0.0779 - val_accuracy: 0.9804
# Epoch 16/100
# 90/90 [==============================] - 4s 45ms/step - loss: 0.0554 - accuracy: 0.9852 - val_loss: 0.0859 - val_accuracy: 0.9782
# Epoch 17/100
# 90/90 [==============================] - 4s 45ms/step - loss: 0.0504 - accuracy: 0.9863 - val_loss: 0.0822 - val_accuracy: 0.9797
# Epoch 18/100
# 90/90 [==============================] - 4s 46ms/step - loss: 0.0457 - accuracy: 0.9878 - val_loss: 0.0778 - val_accuracy: 0.9809
# Epoch 19/100
# 90/90 [==============================] - 4s 44ms/step - loss: 0.0432 - accuracy: 0.9884 - val_loss: 0.0764 - val_accuracy: 0.9807
# Epoch 20/100
# 90/90 [==============================] - 4s 44ms/step - loss: 0.0390 - accuracy: 0.9895 - val_loss: 0.0722 - val_accuracy: 0.9820
# Epoch 21/100
# 90/90 [==============================] - 4s 44ms/step - loss: 0.0356 - accuracy: 0.9905 - val_loss: 0.0788 - val_accuracy: 0.9805
# Epoch 22/100
# 90/90 [==============================] - 4s 44ms/step - loss: 0.0335 - accuracy: 0.9910 - val_loss: 0.0693 - val_accuracy: 0.9829
# Epoch 23/100
# 90/90 [==============================] - 4s 44ms/step - loss: 0.0309 - accuracy: 0.9916 - val_loss: 0.0708 - val_accuracy: 0.9832
# Epoch 24/100
# 90/90 [==============================] - 4s 44ms/step - loss: 0.0289 - accuracy: 0.9921 - val_loss: 0.0703 - val_accuracy: 0.9827
# Epoch 25/100
# 90/90 [==============================] - 4s 44ms/step - loss: 0.0268 - accuracy: 0.9927 - val_loss: 0.0753 - val_accuracy: 0.9814
# Epoch 26/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0249 - accuracy: 0.9932 - val_loss: 0.0691 - val_accuracy: 0.9834
# Epoch 27/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0232 - accuracy: 0.9936 - val_loss: 0.0746 - val_accuracy: 0.9822
# Epoch 28/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0221 - accuracy: 0.9943 - val_loss: 0.0704 - val_accuracy: 0.9832
# Epoch 29/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0200 - accuracy: 0.9947 - val_loss: 0.0763 - val_accuracy: 0.9812
# Epoch 30/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0189 - accuracy: 0.9950 - val_loss: 0.0700 - val_accuracy: 0.9838
# Epoch 31/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0182 - accuracy: 0.9951 - val_loss: 0.0749 - val_accuracy: 0.9820
# Epoch 32/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0167 - accuracy: 0.9955 - val_loss: 0.0738 - val_accuracy: 0.9832
# Epoch 33/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0150 - accuracy: 0.9960 - val_loss: 0.0751 - val_accuracy: 0.9826
# Epoch 34/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0145 - accuracy: 0.9961 - val_loss: 0.0751 - val_accuracy: 0.9831
# Epoch 35/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0133 - accuracy: 0.9965 - val_loss: 0.0830 - val_accuracy: 0.9817
# Epoch 36/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 0.0786 - val_accuracy: 0.9827
# Epoch 37/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 0.0742 - val_accuracy: 0.9832
# Epoch 38/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.0792 - val_accuracy: 0.9827
# Epoch 39/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 0.0811 - val_accuracy: 0.9823
# Epoch 40/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.0776 - val_accuracy: 0.9830
# Epoch 41/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0096 - accuracy: 0.9976 - val_loss: 0.0795 - val_accuracy: 0.9836
# Epoch 42/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.0793 - val_accuracy: 0.9834
# Epoch 43/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.0793 - val_accuracy: 0.9833
# Epoch 44/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.0797 - val_accuracy: 0.9835
# Epoch 45/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.0818 - val_accuracy: 0.9836
# Epoch 46/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0077 - accuracy: 0.9981 - val_loss: 0.0806 - val_accuracy: 0.9828
# Epoch 47/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.0836 - val_accuracy: 0.9837
# Epoch 48/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.0843 - val_accuracy: 0.9830
# Epoch 49/100
# 90/90 [==============================] - 4s 43ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.0825 - val_accuracy: 0.9836
# Epoch 50/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0893 - val_accuracy: 0.9828
# Epoch 51/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.0828 - val_accuracy: 0.9832
# Epoch 52/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 0.0872 - val_accuracy: 0.9828
# Epoch 53/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0853 - val_accuracy: 0.9832
# Epoch 54/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0857 - val_accuracy: 0.9834
# Epoch 55/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.0881 - val_accuracy: 0.9830
# Epoch 56/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.0867 - val_accuracy: 0.9828
# Epoch 57/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.0891 - val_accuracy: 0.9832
# Epoch 58/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0903 - val_accuracy: 0.9825
# Epoch 59/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0945 - val_accuracy: 0.9830
# Epoch 60/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0961 - val_accuracy: 0.9822
# Epoch 61/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0932 - val_accuracy: 0.9835
# Epoch 62/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0895 - val_accuracy: 0.9833
# Epoch 63/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0912 - val_accuracy: 0.9833
# Epoch 64/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.1009 - val_accuracy: 0.9822
# Epoch 65/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0906 - val_accuracy: 0.9832
# Epoch 66/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0963 - val_accuracy: 0.9825
# Epoch 67/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0957 - val_accuracy: 0.9830
# Epoch 68/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0931 - val_accuracy: 0.9825
# Epoch 69/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.1070 - val_accuracy: 0.9813
# Epoch 70/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0975 - val_accuracy: 0.9831
# Epoch 71/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0988 - val_accuracy: 0.9828
# Epoch 72/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0958 - val_accuracy: 0.9832
# Epoch 73/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0981 - val_accuracy: 0.9832
# Epoch 74/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0998 - val_accuracy: 0.9837
# Epoch 75/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0987 - val_accuracy: 0.9827
# Epoch 76/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0960 - val_accuracy: 0.9832
# Epoch 77/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0985 - val_accuracy: 0.9828
# Epoch 78/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.1000 - val_accuracy: 0.9828
# Epoch 79/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0989 - val_accuracy: 0.9834
# Epoch 80/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.1013 - val_accuracy: 0.9830
# Epoch 81/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.1024 - val_accuracy: 0.9827
# Epoch 82/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.1066 - val_accuracy: 0.9821
# Epoch 83/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0105 - accuracy: 0.9975 - val_loss: 0.1057 - val_accuracy: 0.9815
# Epoch 84/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.0997 - val_accuracy: 0.9826
# Epoch 85/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.0969 - val_accuracy: 0.9828
# Epoch 86/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0942 - val_accuracy: 0.9836
# Epoch 87/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.1017 - val_accuracy: 0.9827
# Epoch 88/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0989 - val_accuracy: 0.9832
# Epoch 89/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.1035 - val_accuracy: 0.9827
# Epoch 90/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0960 - val_accuracy: 0.9836
# Epoch 91/100
# 90/90 [==============================] - 4s 42ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0998 - val_accuracy: 0.9824
# Epoch 92/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.1029 - val_accuracy: 0.9829
# Epoch 93/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1024 - val_accuracy: 0.9830
# Epoch 94/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1042 - val_accuracy: 0.9830
# Epoch 95/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1028 - val_accuracy: 0.9833
# Epoch 96/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1033 - val_accuracy: 0.9833
# Epoch 97/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.1058 - val_accuracy: 0.9832
# Epoch 98/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1046 - val_accuracy: 0.9830
# Epoch 99/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1061 - val_accuracy: 0.9832
# Epoch 100/100
# 90/90 [==============================] - 4s 41ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1075 - val_accuracy: 0.9828
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2s/assets
# INFO:tensorflow:Assets written to: s2s/assets

# %%
from tensorflow.keras.utils import plot_model
plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)

# %%
import matplotlib.pyplot as plt
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# testing with validation

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs1, forw_state_h, forw_state_c, back_state_h, back_state_c = model.layers[1].output # lstm_1
state_h_enc = Concatenate()([forw_state_h, back_state_h])
state_c_enc = Concatenate()([forw_state_c, back_state_c])
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=((2*latent_dim),), name="input_7")
decoder_state_input_c = keras.Input(shape=((2*latent_dim),), name="input_5")
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[5]
initial_state=decoder_states_inputs
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(decoder_inputs, initial_state=initial_state)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[6]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: la
# Decoded sentence: la
#
# -
# Input sentence: gente
# Decoded sentence: gente
#
# -
# Input sentence: no
# Decoded sentence: no
#
# -
# Input sentence: cambia
# Decoded sentence: cambia
#
# -
# Input sentence: por
# Decoded sentence: por
#
# -
# Input sentence: que
# Decoded sentence: que
#
# -
# Input sentence: quiere,
# Decoded sentence: quiere
#
# -
# Input sentence: sino
# Decoded sentence: sino
#
# -
# Input sentence: por
# Decoded sentence: por
#
# -
# Input sentence: que
# Decoded sentence: que
#
# -
# Input sentence: le
# Decoded sentence: le
#
# -
# Input sentence: hicieron
# Decoded sentence: hicieron
#
# -
# Input sentence: daño
# Decoded sentence: daño
#
# -
# Input sentence: y
# Decoded sentence: y
#
# -
# Input sentence: se
# Decoded sentence: se
#
# -
# Input sentence: vio
# Decoded sentence: vio
#
# -
# Input sentence: obligada
# Decoded sentence: obligada
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: dejar
# Decoded sentence: dejar
#
# -
# Input sentence: de
# Decoded sentence: de
#
# -
# Input sentence: ser
# Decoded sentence: ser
#
# -
# Input sentence: quien
# Decoded sentence: quien
#
# -
# Input sentence: era
# Decoded sentence: era
#
# -
# Input sentence: ..
# Decoded sentence: ..
#
# -
# Input sentence: hoy
# Decoded sentence: hoy
#
# -
# Input sentence: llevo
# Decoded sentence: llevo
#
# -
# Input sentence: la
# Decoded sentence: la
#
# -
# Input sentence: camiseta
# Decoded sentence: camiseta
#
# -
# Input sentence: de
# Decoded sentence: de
#
# -
# Input sentence: batman
# Decoded sentence: batman
#
# -
# Input sentence: jdjejdkahflwkdjwpvqh
# Decoded sentence: jdjejdkahflwkdjwpvqh
#
# -
# Input sentence: .
# Decoded sentence: .
#
# -
# Input sentence: el
# Decoded sentence: el
#
# -
# Input sentence: siestón
# Decoded sentence: siestón
#
# -
# Input sentence: que
# Decoded sentence: que
#
# -
# Input sentence: me
# Decoded sentence: me
#
# -
# Input sentence: voy
# Decoded sentence: voy
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: echar
# Decoded sentence: echar
#
# -
# Input sentence: hoy
# Decoded sentence: hoy
#
# -
# Input sentence: va
# Decoded sentence: va
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: ser
# Decoded sentence: ser
#
# -
# Input sentence: digno...!
# Decoded sentence: digno...!
#
# -
# Input sentence: @xheartbreaker_
# Decoded sentence: @xheartbreaker_
#
# -
# Input sentence: ay
# Decoded sentence: ay
#
# -
# Input sentence: dios,
# Decoded sentence: dios
#
# -
# Input sentence: hoy
# Decoded sentence: hoy
#
# -
# Input sentence: acabo
# Decoded sentence: acabo
#
# -
# Input sentence: en
# Decoded sentence: en
#
# -
# Input sentence: el
# Decoded sentence: el
#
# -
# Input sentence: hospital
# Decoded sentence: hospital
#
# -
# Input sentence: por
# Decoded sentence: por
#
# -
# Input sentence: ataques.
# Decoded sentence: ataques.
#
# -
# Input sentence: esperando
# Decoded sentence: esperando
#
# -
# Input sentence: walking
# Decoded sentence: walking
#
# -
# Input sentence: dead
# Decoded sentence: dead
#
# -
# Input sentence: .
# Decoded sentence: .
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: ver
# Decoded sentence: ver
#
# -
# Input sentence: como
# Decoded sentence: como
#
# -
# Input sentence: acaba...
# Decoded sentence: acaba...
#
# -
# Input sentence: @ursulaa5
# Decoded sentence: @ursulaa5
#
# -
# Input sentence: me
# Decoded sentence: me
#
# -
# Input sentence: esquivocao
# Decoded sentence: he_equivocado
#
# -
# Input sentence: y
# Decoded sentence: y
#
# -
# Input sentence: estoy
# Decoded sentence: estoy
#
# -
# Input sentence: en
# Decoded sentence: en
#
# -
# Input sentence: el
# Decoded sentence: el
#
# -
# Input sentence: donald
# Decoded sentence: donald
#
# -
# Input sentence: del
# Decoded sentence: del
#
# -
# Input sentence: piolin
# Decoded sentence: piolín
#
# -
# Input sentence: ya
# Decoded sentence: ya
#
# -
# Input sentence: estoy
# Decoded sentence: estoy
#
# -
# Input sentence: yendo.
# Decoded sentence: yendo.
#
# -
# Input sentence: http://t.co/q9kq4daxfv
# Decoded sentence: http://t.co/q9kq4daxfv
#
# -
# Input sentence: @cristinasorisa
# Decoded sentence: @cristinasorisa
#
# -
# Input sentence: @lorenahl16
# Decoded sentence: @lorenahl16
#
# -
# Input sentence: @rocioortiz954
# Decoded sentence: @rociorro_ti954
#
# -
# Input sentence: @pilar_2212
# Decoded sentence: @pilar_2212
#
# -
# Input sentence: @silvia_sg_95
# Decoded sentence: @silvia_sg_95
#
# -
# Input sentence: de
# Decoded sentence: de
#
# -
# Input sentence: paluegos
# Decoded sentence: paluegos
#
# -
# Input sentence: del
# Decoded sentence: del
#
# -
# Input sentence: fanegol
# Decoded sentence: fanegol
#
# -
# Input sentence: jajajajajajajajajjajajajajajaja
# Decoded sentence: ja
#
# -
# Input sentence: me
# Decoded sentence: me
#
# -
# Input sentence: meoooo
# Decoded sentence: meo
#
# -
# Input sentence: *
# Decoded sentence: *
#
# -
# Input sentence: vega
# Decoded sentence: vega
#
# -
# Input sentence: del
# Decoded sentence: del
#
# -
# Input sentence: codorno
# Decoded sentence: codorno
#
# -
# Input sentence: *
# Decoded sentence: *
#
# -
# Input sentence: actualizado:
# Decoded sentence: actualizado:
#
# -
# Input sentence: 02-04-2013
# Decoded sentence: 02-04-2013
#
# -
# Input sentence: 05:02
# Decoded sentence: 05:02
#
# -
# Input sentence: utc
# Decoded sentence: utc
#
# -
# Input sentence: *
# Decoded sentence: *
#
# -
# Input sentence: temperatura:
# Decoded sentence: temperatura:
#
# -
# Input sentence: 2,1
# Decoded sentence: 2,1
