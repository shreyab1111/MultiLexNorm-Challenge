# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyab1111/MultiLexNorm-Challenge/blob/main/Italian/it_ln_seq2seq_biLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Embedding, Concatenate
from tensorflow.keras import Input, Model

# %% [markdown]
# German

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 128  # Latent dimensionality of the encoding space.
num_samples = 30000  # Number of samples to train on.
data_path = '/content/drive/MyDrive/NLP/Lexical Normalisation/Multilexnorm Challenge/Italian/it.train.norm.txt'

# %% [markdown]
# Character encoding

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r") as f:
    lines = f.readlines()
for line in lines[: min(num_samples, len(lines) - 1)]:
  if line=='\n':
    continue
  else:
    input_text, target_text= line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)
# Out:
# Number of samples: 12645
# Number of unique input tokens: 133
# Number of unique output tokens: 134
# Max sequence length for inputs: 56
# Max sequence length for outputs: 59

# %%
input_texts
# Out:
# ['STO',
#  'MALE',
#  ':c',
#  '#rt',
#  'seguimi',
#  'ti',
#  'seguo',
#  'e',
#  'ti',
#  'faccio',
#  'una',
#  'domanda',
#  '..',
#  'mi',
#  'annoio',
#  ':c',
#  '#follow',
#  '#followme',
#  'x9',
#  'Crosetto',
#  ':',
#  '"',
#  'Monti',
#  'trovi',
#  'soluzioni',
#  'reali',
#  '"',
#  ':',
#  '#governo',
#  '#guido',
#  'crosetto',
#  '#mario',
#  'monti',
#  'ROMA',
#  '–',
#  "''",
#  'Occorre',
#  'permettere',
#  'a',
#  'que...',
#  'http://t.co/9ibXLgRf',
#  'Ho',
#  'appena',
#  'acquistato',
#  'Ballerina',
#  'Necklace',
#  'su',
#  'Stardoll',
#  '.',
#  'Dai',
#  "un'",
#  'occhiata',
#  'alla',
#  'mia',
#  'Suite',
#  '!',
#  'http://t.co/4izCbBod',
#  'Crisi',
#  ',',
#  'Fitch',
#  ':',
#  'tagli',
#  'più',
#  'severi',
#  'evitati',
#  'grazie',
#  'a',
#  'governo',
#  'Monti',
#  ':',
#  'New',
#  'York',
#  ',',
#  '27',
#  'gen',
#  '.',
#  '(',
#  'TMNews',
#  ')',
#  '?',
#  '"',
#  "Un'",
#  'azione',
#  'più',
#  'sever...',
#  'http://t.co/noUM2hJi',
#  '-',
#  'Mamma',
#  'domani',
#  'torno',
#  '.',
#  'Che',
#  'clima',
#  "c'",
#  'è',
#  'a',
#  'Roma',
#  '?',
#  'Fa',
#  'così',
#  'caldo',
#  '?',
#  '-',
#  'Mah',
#  '.',
#  'È',
#  'un',
#  'autunnello',
#  'primaveretta',
#  'caldino',
#  'caldino',
#  'Mia',
#  'madre',
#  'è',
#  'Ned',
#  'Flanders',
#  '?',
#  'Corsera',
#  ':',
#  'I',
#  'caroselli',
#  'e',
#  'i',
#  'fischi',
#  'in',
#  'piazza',
#  'hanno',
#  'guastato',
#  "l'",
#  'umore',
#  'a',
#  'B.',
#  'e',
#  'ai',
#  'suoi',
#  'che',
#  'induriscono',
#  'le',
#  'condizioni',
#  'per',
#  'dire',
#  'di',
#  'sì',
#  'al',
#  'governo',
#  'Monti',
#  'x:',
#  'Ti',
#  'sei',
#  'commosso',
#  'dopo',
#  'lo',
#  'show',
#  'vero',
#  '?',
#  'Harry',
#  ':',
#  'Sì',
#  'sono',
#  'molto',
#  'affezionato',
#  "all'",
#  'Italia',
#  '*--*',
#  'http://t.co/5pO2PXK3',
#  'la',
#  'politica',
#  'sulla',
#  'crescita',
#  'del',
#  'governo',
#  'Monti',
#  'è',
#  'più',
#  'criptica',
#  'degli',
#  'errori',
#  'di',
#  'Windows',
#  'sul',
#  'registro',
#  'eventi',
#  '.',
#  'Ho',
#  'letto',
#  'la',
#  'lista',
#  'dei',
#  'ministri',
#  'del',
#  'governo',
#  'Monti',
#  'e',
#  'parecchi',
#  'mi',
#  'sembrano',
#  'inadatti',
#  'al',
#  'ministero',
#  'che',
#  'gli',
#  'è',
#  'stato',
#  'dato',
#  '!',
#  'IL',
#  'GOVERNO',
#  '#MONTI',
#  'E',
#  'LA',
#  '#CENSURA',
#  'DEI',
#  '#VIDEO',
#  'SULLA',
#  '#RIVOLUZIONE',
#  'DEI',
#  '#FORCONI',
#  '.',
#  'http://t.co/ywdC04Wy',
#  'RT',
#  '@ehilapayne',
#  ':',
#  'QUANDO',
#  'CAPIRETE',
#  'CHE',
#  'NON',
#  'CREDERE',
#  'NELLA',
#  'ZERRIE',
#  'NON',
#  'CORRISPONDE',
#  'AD',
#  'ODIARE',
#  'PERRIE',
#  'O',
#  'INSULTARLA',
#  'ALL',
#  'DAY',
#  'ALL',
#  'NIGHT',
#  '?',
#  'MINCHIA',
#  'AVETE',
#  '…',
#  'Ferrero',
#  '(',
#  'PRC',
#  ')',
#  'propone',
#  'a',
#  'Vendola',
#  '(',
#  'SEL',
#  ')',
#  'unità',
#  'a',
#  'sinistra',
#  'contro',
#  'Governo',
#  'Monti',
#  '|',
#  'umbrialeft.it',
#  'http://t.co/NCBBMZB3',
#  'Se',
#  'nel',
#  'governo',
#  'Monti',
#  'entrano',
#  'anche',
#  'i',
#  'ministri',
#  'del',
#  'governo',
#  'Berlusconi',
#  'come',
#  'si',
#  'fa',
#  'ad',
#  'avvicinarsi',
#  '.',
#  'Quelli',
#  'hanno',
#  'rovinato',
#  'il',
#  'Paese',
#  '.',
#  'Non',
#  'si',
#  'può',
#  '@Jughernaut',
#  'si',
#  'anche',
#  'quello',
#  ',',
#  'ma',
#  'soprattutto',
#  'fammi',
#  'sapere',
#  'xD',
#  'cioè',
#  'non',
#  'è',
#  'un',
#  'trofeo',
#  ',',
#  'è',
#  'una',
#  'proposta',
#  'vera',
#  'e',
#  'propria',
#  '!',
#  'Ahahah',
#  'guarda',
#  'te',
#  'che',
#  'sogget',
#  'Italo',
#  'Bocchino',
#  ':',
#  'Se',
#  'il',
#  'governo',
#  'Monti',
#  'non',
#  'piace',
#  'alla',
#  'Lega',
#  ',',
#  'a',
#  'Di',
#  'Pietro',
#  'e',
#  'a',
#  'Sallusti',
#  'allora',
#  'significa',
#  'che',
#  'è',
#  'il',
#  'governo',
#  'che',
#  'serve',
#  'al',
#  'Paese',
#  '.',
#  'La',
#  'storia',
#  ',',
#  'le',
#  'luci',
#  'e',
#  'le',
#  'ombre',
#  'dei',
#  'neoministri',
#  'del',
#  'governo',
#  '#Monti',
#  '|',
#  'Diritto',
#  'di',
#  'critica',
#  'http://t.co/J7Iw2r2P',
#  'via',
#  '@ddcnews',
#  '#ministri',
#  'RT',
#  '@harrysbooks',
#  ':',
#  '“',
#  '@pottervato',
#  ':',
#  'se',
#  'ci',
#  'fosse',
#  'demi',
#  'direbbe',
#  'che',
#  'sono',
#  'un',
#  'mashup',
#  'tra',
#  'i',
#  'jonas',
#  'e',
#  'gli',
#  'one',
#  'direction',
#  'uscito',
#  'male',
#  '.',
#  '#xf7',
#  '”',
#  'È',
#  'VERO',
#  'AHAHAH',
#  '…',
#  'Ippica',
#  'sul',
#  'lastrico',
#  ':',
#  'cavalli',
#  'macellati',
#  'e',
#  'famiglie',
#  'legate',
#  "all'",
#  'indotto',
#  'in',
#  'crisi',
#  '.',
#  'Le',
#  'prime',
#  'vittime',
#  'del',
#  'governo',
#  'Monti',
#  '.',
#  'http://t.co/UtCFqacR',
#  'pensavo',
#  'che',
#  '#lalettura',
#  'fosse',
#  'un',
#  'agguerrito',
#  'think',
#  'tank',
#  'della',
#  'cultura',
#  'neoliberista',
#  'e',
#  'invece',
#  'è',
#  'solo',
#  'una',
#  'ciofeca',
#  'e',
#  'poi',
#  ',',
#  'io',
#  'devo',
#  'ancora',
#  'guardarmi',
#  'il',
#  'docu-film',
#  'sui',
#  'doors',
#  'narrato',
#  'da',
#  'Morgan',
#  ',',
#  'ma',
#  'non',
#  'ce',
#  'la',
#  'faccio',
#  '.',
#  'è',
#  'più',
#  'forte',
#  'di',
#  'me',
#  '.',
#  '@g79world',
#  'abiamo',
#  'cancellato',
#  'contatti',
#  'da',
#  'pc',
#  '.',
#  'li',
#  'ho',
#  'su',
#  'iphone',
#  '.',
#  'con',
#  'sincro',
#  'perdo',
#  'tutto',
#  '.',
#  'devo',
#  'importare',
#  'da',
#  'iphone',
#  'su',
#  'outlook',
#  'ma',
#  'non',
#  'ghe',
#  'la',
#  'fò',
#  '!',
#  'Twitter',
#  ':',
#  'Saviano',
#  'e',
#  'Grillo',
#  'tra',
#  "piu'",
#  'influenti',
#  'Italia',
#  '-',
#  'Photostory',
#  'Curiosità',
#  '-',
#  'ANSA.it',
#  'http://t.co/q3F2cqRP',
#  'via',
#  '@ansa_topnews',
#  'Maroni',
#  ':',
#  '"',
#  'Tifo',
#  'per',
#  'Cancellieri',
#  'o',
#  'Mosca',
#  'agli',
#  'Interni',
#  '"',
#  ':',
#  '#anna',
#  'maria',
#  'cancellieri',
#  '#governo',
#  '#mario',
#  'monti',
#  'ROMA',
#  ',',
#  '15',
#  'NOV',
#  '...',
#  'http://t.co/BWtHaey2',
#  'Enrico',
#  'Mentana',
#  ':',
#  '«',
#  'Il',
#  'successo',
#  '(',
#  'possibile',
#  ')',
#  'di',
#  '#Grillo',
#  'è',
#  'un',
#  'effetto',
#  ',',
#  'non',
#  'una',
#  'causa',
#  'della',
#  '#crisi',
#  'dei',
#  '#partiti',
#  '»',
#  'http://t.co/TjRBsXML',
#  'Bersani',
#  ':',
#  '«',
#  'Governo',
#  'Monti',
#  'punti',
#  'al',
#  'cuore',
#  'degli',
#  'italiani',
#  '»',
#  '.',
#  'Il',
#  'fegato',
#  'se',
#  'lo',
#  'sono',
#  'rovinati',
#  'col',
#  'governo',
#  'Berlusconi',
#  '.',
#  'Grillini',
#  ',',
#  'imparate',
#  'a',
#  'confrontarvi',
#  'con',
#  'gli',
#  'altri',
#  ',',
#  'non',
#  'insultate',
#  '.',
#  '#Grillo',
#  'non',
#  'vi',
#  'ha',
#  'insegnato',
#  'che',
#  'il',
#  'confronto',
#  'è',
#  'alla',
#  'base',
#  'della',
#  'democrazia',
#  '?',
#  '#Grillo',
#  'che',
#  'scappa',
#  'da',
#  'Bertazzoni',
#  '.',
#  'Sembra',
#  'più',
#  'una',
#  'burla',
#  ',',
#  'girando',
#  'attorno',
#  'al',
#  'camper',
#  '.',
#  'Paragonarlo',
#  'a',
#  'tutti',
#  'gli',
#  'altri',
#  'è',
#  'troppo',
#  'http://t.co/REqlY32k',
#  'Fettucini',
#  'alla',
#  'Amatriciana',
#  '@username',
#  'Ama',
#  'Ristorante',
#  'in',
#  'Atlantic',
#  'Highlands',
#  ',',
#  'NJ',
#  '.',
#  'Call',
#  '732-872-4674',
#  '!',
#  'POLITICA',
#  '.',
#  '#Panebianco',
#  'sul',
#  'CorSera',
#  ':',
#  'La',
#  'durata',
#  'e',
#  'la',
#  'stabilità',
#  'del',
#  'governo',
#  'Monti',
#  'non',
#  'hanno',
#  'nulla',
#  'a',
#  'che',
#  'fare',
#  'con',
#  'la',
#  'questione',
#  'del',
#  '#referendum',
#  '.',
#  'Si',
#  "all'",
#  'Europa',
#  'no',
#  "all'",
#  'EuroBANCA',
#  '!',
#  'No',
#  'a',
#  'Mario',
#  'Monti',
#  '#nomonti',
#  '@SurFilWave',
#  '@TullioApi',
#  '@GiorgiaUlgiati',
#  '@valesalomo',
#  '@VALERIA_GENOVA',
#  '@swaggiee_',
#  'mmmh',
#  '..',
#  'va',
#  'bene',
#  'frà',
#  '?',
#  'io',
#  'chiamo',
#  'tutti',
#  'così',
#  '(',
#  'es',
#  '.',
#  'monica',
#  '->',
#  'mò',
#  ')',
#  '#LOL',
#  'Manovra',
#  'governo',
#  'Monti',
#  'si',
#  'parla',
#  'di',
#  'tassa',
#  'sul',
#  'lusso',
#  '.',
#  'Una',
#  'tantum',
#  'sulle',
#  'sciarpe',
#  'oltre',
#  'i',
#  '50',
#  'centimentri',
#  '.',
#  'Vabbene',
#  'scaldarsi',
#  '...',
#  'Cosa',
#  'ne',
#  'pensate',
#  'della',
#  'mia',
#  'nuova',
#  '"',
#  'icons',
#  '"',
#  '(',
#  'si',
#  'dice',
#  'così',
#  '?',
#  ')',
#  'su',
#  'twitter',
#  '??',
#  'Se',
#  'la',
#  'prendete',
#  '"',
#  'creditate',
#  '"',
#  'la',
#  'pagina',
#  '<3',
#  'http://t.co/SUfFXKdb',
#  'RT',
#  '@xxzaynslaughj',
#  ':',
#  '#rt',
#  'seguimi',
#  'e',
#  'ti',
#  'seguo',
#  ',',
#  'aumenti',
#  'tu',
#  'e',
#  'aumento',
#  "anch'",
#  'io',
#  '.',
#  'E',
#  'ti',
#  'voto',
#  "l'",
#  'icon',
#  'se',
#  'aggiungi',
#  'ai',
#  'preferiti',
#  '❤',
#  'Per',
#  'il',
#  '#M5S',
#  'è',
#  'presente',
#  "all'",
#  'incontro',
#  'la',
#  'dott.ssa',
#  'Loredana',
#  'Mannina',
#  ',',
#  'assessore',
#  'della',
#  'giunta',
#  'Nuti',
#  '#elepa',
#  '#openPalermo',
#  'http://t.co/9bCDrhi4',
#  '@juanmjm',
#  'RIFORMA',
#  ':',
#  'una',
#  'delle',
#  'tante',
#  'che',
#  'i',
#  'partiti',
#  'hanno',
#  'imposto',
#  '(',
#  'ahahhha',
#  ')',
#  'al',
#  'Governo',
#  'Monti',
#  '.',
#  '#puttanate',
#  '#campacavallochelerbacresce',
#  'Si',
#  "all'",
#  'Europa',
#  'no',
#  "all'",
#  'EuroBANCA',
#  '!',
#  'No',
#  'a',
#  'Mario',
#  'Monti',
#  '#nomonti',
#  '@CristianAlicata',
#  '@CarloTramontano',
#  '@Diletta_Ale',
#  '@DianaFabrizi',
#  '@donzelli',
#  'RT',
#  '@MarcoPetrone4',
#  ':',
#  'Confcommercio',
#  ':',
#  'Stangata',
#  'per',
#  'le',
#  'imprese',
#  'con',
#  'la',
#  'nuova',
#  'tassa',
#  'sui',
#  'rifiuti',
#  'urbani',
#  '.',
#  "L'",
#  'aumento',
#  'medio',
#  'dei',
#  'costi',
#  'nel',
#  '2014',
#  'sarà',
#  'pa...',
#  'The',
#  'Italian',
#  'job',
#  ':',
#  'la',
#  'risposta',
#  'degli',
#  'italiani',
#  'a',
#  'Mario',
#  'Monti',
#  'http://t.co/7ZHAdpZr',
#  'via',
#  '@addthis',
#  '@capatesuspigolo',
#  '@MicheleCatalano',
#  'a',
#  'Mattino5',
#  'il',
#  'vicedirettore',
#  'di',
#  'Chi',
#  'parla',
#  'della',
#  'copertina',
#  'con',
#  'Barbara',
#  'e',
#  'la',
#  'Fedenon',
#  'ha',
#  'proferito',
#  'parola',
#  '.',
#  'Post',
#  'Terremoto',
#  'in',
#  'Molise',
#  ':',
#  'gli',
#  'EcoDem',
#  'chiedono',
#  'risposte',
#  'concrete',
#  'da',
#  'Governo',
#  'Monti',
#  ':',
#  'LARINO',
#  '_',
#  'Per',
#  "l'",
#  'Associazione',
#  'Ec...',
#  'http://t.co/wYbeo0zX',
#  '#serviziopubblico',
#  'Grazie',
#  'a',
#  '#Renzi',
#  'e',
#  '#Grillo',
#  'sono',
#  'arrivato',
#  'al',
#  'record',
#  'di',
#  'ascolto',
#  'di',
#  'trasm',
#  '.',
#  'politiche',
#  'negli',
#  'ultimi',
#  'tempi',
#  '...',
#  'ben',
#  '7',
#  "'",
#  'di',
#  'dialoghi',
#  '!',
#  'TT',
#  'Twitter',
#  'Italia',
#  '04:00',
#  ':',
#  '1',
#  '.',
#  '#cinemaInChiesa',
#  '2',
#  '.',
#  '#serviziopubblico',
#  '3',
#  '.',
#  '#Grillo',
#  '4',
#  '.',
#  'Trota',
#  '5',
#  '.',
#  'Levon',
#  'Helm',
#  '6',
#  '.',
#  'Prince',
#  'Of',
#  'Persia',
#  '7',
#  '.',
#  'Damon',
#  'and',
#  'Elena',
#  '8',
#  '.',
#  'Lega',
#  'Sondaggio',
#  'del',
#  'Messaggero.it',
#  ':',
#  "l'",
#  '80',
#  '%',
#  'dei',
#  'lettori',
#  'dice',
#  'sì',
#  'al',
#  'governo',
#  'Monti',
#  'http://t.co/aQbnn8jg',
#  'ELENA',
#  'UGOLINI',
#  ',',
#  'la',
#  'nuova',
#  ...]

# %% [markdown]
# encoder_input_data is a 3D array of shape (num_pairs, max_english_sentence_length, num_english_characters) containing a one-hot vectorization of the English sentences.
#
# decoder_input_data is a 3D array of shape (num_pairs, max_french_sentence_length, num_french_characters) containg a one-hot vectorization of the French sentences.
#
# decoder_target_data is the same as decoder_input_data but offset by one timestep. decoder_target_data[:, t, :] will be the same as decoder_input_data[:, t + 1, :].

# %%
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

# %% [markdown]
# one hot rep

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[',']] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, (t + 1):, target_token_index[',']] = 1.0
    decoder_target_data[i, t:, target_token_index[',']] = 1.0

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = Bidirectional(LSTM(latent_dim, return_state=True, return_sequences=True))
encoder_outputs1, forw_state_h, forw_state_c, back_state_h, back_state_c = encoder(encoder_inputs)

state_h = Concatenate()([forw_state_h, back_state_h])
state_c = Concatenate()([forw_state_c, back_state_c])

encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM((2*latent_dim), return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 159/159 [==============================] - 21s 70ms/step - loss: 0.4624 - accuracy: 0.8972 - val_loss: 0.5257 - val_accuracy: 0.8411
# Epoch 2/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.2671 - accuracy: 0.9309 - val_loss: 0.2611 - val_accuracy: 0.9314
# Epoch 3/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.1915 - accuracy: 0.9506 - val_loss: 0.1854 - val_accuracy: 0.9507
# Epoch 4/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.1375 - accuracy: 0.9640 - val_loss: 0.1242 - val_accuracy: 0.9666
# Epoch 5/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.1012 - accuracy: 0.9734 - val_loss: 0.1053 - val_accuracy: 0.9732
# Epoch 6/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0766 - accuracy: 0.9806 - val_loss: 0.1439 - val_accuracy: 0.9647
# Epoch 7/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0600 - accuracy: 0.9850 - val_loss: 0.1034 - val_accuracy: 0.9735
# Epoch 8/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0493 - accuracy: 0.9879 - val_loss: 0.0581 - val_accuracy: 0.9855
# Epoch 9/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0416 - accuracy: 0.9898 - val_loss: 0.0541 - val_accuracy: 0.9865
# Epoch 10/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0363 - accuracy: 0.9911 - val_loss: 0.0612 - val_accuracy: 0.9843
# Epoch 11/100
# 159/159 [==============================] - 9s 57ms/step - loss: 0.0320 - accuracy: 0.9922 - val_loss: 0.0417 - val_accuracy: 0.9902
# Epoch 12/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0285 - accuracy: 0.9930 - val_loss: 0.0437 - val_accuracy: 0.9892
# Epoch 13/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0275 - accuracy: 0.9932 - val_loss: 0.0374 - val_accuracy: 0.9912
# Epoch 14/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0231 - accuracy: 0.9942 - val_loss: 0.0441 - val_accuracy: 0.9893
# Epoch 15/100
# 159/159 [==============================] - 9s 57ms/step - loss: 0.0211 - accuracy: 0.9947 - val_loss: 0.0479 - val_accuracy: 0.9891
# Epoch 16/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0194 - accuracy: 0.9951 - val_loss: 0.0352 - val_accuracy: 0.9918
# Epoch 17/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0179 - accuracy: 0.9954 - val_loss: 0.0350 - val_accuracy: 0.9921
# Epoch 18/100
# 159/159 [==============================] - 9s 57ms/step - loss: 0.0166 - accuracy: 0.9957 - val_loss: 0.0407 - val_accuracy: 0.9912
# Epoch 19/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0152 - accuracy: 0.9961 - val_loss: 0.0412 - val_accuracy: 0.9913
# Epoch 20/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0141 - accuracy: 0.9965 - val_loss: 0.0329 - val_accuracy: 0.9925
# Epoch 21/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.0329 - val_accuracy: 0.9927
# Epoch 22/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0122 - accuracy: 0.9968 - val_loss: 0.0366 - val_accuracy: 0.9916
# Epoch 23/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.0336 - val_accuracy: 0.9926
# Epoch 24/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.0344 - val_accuracy: 0.9924
# Epoch 25/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0098 - accuracy: 0.9974 - val_loss: 0.0328 - val_accuracy: 0.9930
# Epoch 26/100
# 159/159 [==============================] - 9s 57ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0385 - val_accuracy: 0.9918
# Epoch 27/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.0353 - val_accuracy: 0.9921
# Epoch 28/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.0341 - val_accuracy: 0.9929
# Epoch 29/100
# 159/159 [==============================] - 9s 57ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0354 - val_accuracy: 0.9927
# Epoch 30/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0488 - val_accuracy: 0.9897
# Epoch 31/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0349 - val_accuracy: 0.9927
# Epoch 32/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0422 - val_accuracy: 0.9909
# Epoch 33/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.0347 - val_accuracy: 0.9928
# Epoch 34/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0373 - val_accuracy: 0.9923
# Epoch 35/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.0355 - val_accuracy: 0.9927
# Epoch 36/100
# 159/159 [==============================] - 9s 57ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0354 - val_accuracy: 0.9929
# Epoch 37/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0392 - val_accuracy: 0.9920
# Epoch 38/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0390 - val_accuracy: 0.9923
# Epoch 39/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0351 - val_accuracy: 0.9930
# Epoch 40/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0365 - val_accuracy: 0.9928
# Epoch 41/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0375 - val_accuracy: 0.9926
# Epoch 42/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0369 - val_accuracy: 0.9929
# Epoch 43/100
# 159/159 [==============================] - 9s 57ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0383 - val_accuracy: 0.9926
# Epoch 44/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0375 - val_accuracy: 0.9928
# Epoch 45/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0387 - val_accuracy: 0.9924
# Epoch 46/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0400 - val_accuracy: 0.9924
# Epoch 47/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0382 - val_accuracy: 0.9927
# Epoch 48/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0401 - val_accuracy: 0.9924
# Epoch 49/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0386 - val_accuracy: 0.9928
# Epoch 50/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0384 - val_accuracy: 0.9927
# Epoch 51/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0399 - val_accuracy: 0.9925
# Epoch 52/100
# 159/159 [==============================] - 9s 57ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0396 - val_accuracy: 0.9928
# Epoch 53/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0419 - val_accuracy: 0.9923
# Epoch 54/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0426 - val_accuracy: 0.9925
# Epoch 55/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0404 - val_accuracy: 0.9925
# Epoch 56/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0409 - val_accuracy: 0.9927
# Epoch 57/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0418 - val_accuracy: 0.9926
# Epoch 58/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0446 - val_accuracy: 0.9920
# Epoch 59/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0416 - val_accuracy: 0.9925
# Epoch 60/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0415 - val_accuracy: 0.9925
# Epoch 61/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0425 - val_accuracy: 0.9925
# Epoch 62/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0415 - val_accuracy: 0.9927
# Epoch 63/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0435 - val_accuracy: 0.9925
# Epoch 64/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0433 - val_accuracy: 0.9924
# Epoch 65/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0425 - val_accuracy: 0.9927
# Epoch 66/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0437 - val_accuracy: 0.9928
# Epoch 67/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0435 - val_accuracy: 0.9925
# Epoch 68/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0435 - val_accuracy: 0.9927
# Epoch 69/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0451 - val_accuracy: 0.9926
# Epoch 70/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0447 - val_accuracy: 0.9926
# Epoch 71/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0436 - val_accuracy: 0.9926
# Epoch 72/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0468 - val_accuracy: 0.9925
# Epoch 73/100
# 159/159 [==============================] - 9s 57ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0449 - val_accuracy: 0.9923
# Epoch 74/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0436 - val_accuracy: 0.9927
# Epoch 75/100
# 159/159 [==============================] - 9s 60ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0436 - val_accuracy: 0.9930
# Epoch 76/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0458 - val_accuracy: 0.9924
# Epoch 77/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0463 - val_accuracy: 0.9923
# Epoch 78/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0442 - val_accuracy: 0.9928
# Epoch 79/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0441 - val_accuracy: 0.9927
# Epoch 80/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0464 - val_accuracy: 0.9923
# Epoch 81/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0470 - val_accuracy: 0.9923
# Epoch 82/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0460 - val_accuracy: 0.9926
# Epoch 83/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0471 - val_accuracy: 0.9927
# Epoch 84/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0481 - val_accuracy: 0.9923
# Epoch 85/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0474 - val_accuracy: 0.9926
# Epoch 86/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0502 - val_accuracy: 0.9921
# Epoch 87/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0474 - val_accuracy: 0.9924
# Epoch 88/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0466 - val_accuracy: 0.9925
# Epoch 89/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0487 - val_accuracy: 0.9925
# Epoch 90/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0479 - val_accuracy: 0.9926
# Epoch 91/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0484 - val_accuracy: 0.9924
# Epoch 92/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0492 - val_accuracy: 0.9925
# Epoch 93/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0497 - val_accuracy: 0.9922
# Epoch 94/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0479 - val_accuracy: 0.9927
# Epoch 95/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0483 - val_accuracy: 0.9925
# Epoch 96/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0487 - val_accuracy: 0.9924
# Epoch 97/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0482 - val_accuracy: 0.9925
# Epoch 98/100
# 159/159 [==============================] - 9s 59ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0489 - val_accuracy: 0.9924
# Epoch 99/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0497 - val_accuracy: 0.9923
# Epoch 100/100
# 159/159 [==============================] - 9s 58ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0497 - val_accuracy: 0.9924
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2s/assets
# INFO:tensorflow:Assets written to: s2s/assets

# %%
from tensorflow.keras.utils import plot_model
plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)

# %%
import matplotlib.pyplot as plt
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# testing with validation

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs1, forw_state_h, forw_state_c, back_state_h, back_state_c = model.layers[1].output # lstm_1
state_h_enc = Concatenate()([forw_state_h, back_state_h])
state_c_enc = Concatenate()([forw_state_c, back_state_c])
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=((2*latent_dim),), name="input_7")
decoder_state_input_c = keras.Input(shape=((2*latent_dim),), name="input_5")
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[5]
initial_state=decoder_states_inputs
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(decoder_inputs, initial_state=initial_state)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[6]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: STO
# Decoded sentence: sto
#
# -
# Input sentence: MALE
# Decoded sentence: male
#
# -
# Input sentence: :c
# Decoded sentence: :c
#
# -
# Input sentence: #rt
# Decoded sentence: #rt
#
# -
# Input sentence: seguimi
# Decoded sentence: seguimi
#
# -
# Input sentence: ti
# Decoded sentence: ti
#
# -
# Input sentence: seguo
# Decoded sentence: seguo
#
# -
# Input sentence: e
# Decoded sentence: e
#
# -
# Input sentence: ti
# Decoded sentence: ti
#
# -
# Input sentence: faccio
# Decoded sentence: faccio
#
# -
# Input sentence: una
# Decoded sentence: una
#
# -
# Input sentence: domanda
# Decoded sentence: domanda
#
# -
# Input sentence: ..
# Decoded sentence: ..
#
# -
# Input sentence: mi
# Decoded sentence: mi
#
# -
# Input sentence: annoio
# Decoded sentence: annoio
#
# -
# Input sentence: :c
# Decoded sentence: :c
#
# -
# Input sentence: #follow
# Decoded sentence: #follow
#
# -
# Input sentence: #followme
# Decoded sentence: #followme
#
# -
# Input sentence: x9
# Decoded sentence: x9
#
# -
# Input sentence: Crosetto
# Decoded sentence: Crosetto
#
# -
# Input sentence: :
# Decoded sentence: :
#
# -
# Input sentence: "
# Decoded sentence: "
#
# -
# Input sentence: Monti
# Decoded sentence: Monti
#
# -
# Input sentence: trovi
# Decoded sentence: trovi
#
# -
# Input sentence: soluzioni
# Decoded sentence: soluzioni
#
# -
# Input sentence: reali
# Decoded sentence: reali
#
# -
# Input sentence: "
# Decoded sentence: "
#
# -
# Input sentence: :
# Decoded sentence: :
#
# -
# Input sentence: #governo
# Decoded sentence: #governo
#
# -
# Input sentence: #guido
# Decoded sentence: #guido
#
# -
# Input sentence: crosetto
# Decoded sentence: Crosetto
#
# -
# Input sentence: #mario
# Decoded sentence: #mario
#
# -
# Input sentence: monti
# Decoded sentence: Monti
#
# -
# Input sentence: ROMA
# Decoded sentence: Roma
#
# -
# Input sentence: –
# Decoded sentence: –
#
# -
# Input sentence: ''
# Decoded sentence: ''
#
# -
# Input sentence: Occorre
# Decoded sentence: Occorre
#
# -
# Input sentence: permettere
# Decoded sentence: permettere
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: que...
# Decoded sentence: que...
#
# -
# Input sentence: http://t.co/9ibXLgRf
# Decoded sentence: http://t.co/9ibXLgRf
#
# -
# Input sentence: Ho
# Decoded sentence: Ho
#
# -
# Input sentence: appena
# Decoded sentence: appena
#
# -
# Input sentence: acquistato
# Decoded sentence: acquistato
#
# -
# Input sentence: Ballerina
# Decoded sentence: Ballerina
#
# -
# Input sentence: Necklace
# Decoded sentence: Necklace
#
# -
# Input sentence: su
# Decoded sentence: su
#
# -
# Input sentence: Stardoll
# Decoded sentence: Stardoll
#
# -
# Input sentence: .
# Decoded sentence: .
#
# -
# Input sentence: Dai
# Decoded sentence: Dai
#
# -
# Input sentence: un'
# Decoded sentence: un'
#
# -
# Input sentence: occhiata
# Decoded sentence: occhiata
#
# -
# Input sentence: alla
# Decoded sentence: alla
#
# -
# Input sentence: mia
# Decoded sentence: mia
#
# -
# Input sentence: Suite
# Decoded sentence: suite
#
# -
# Input sentence: !
# Decoded sentence: !
#
# -
# Input sentence: http://t.co/4izCbBod
# Decoded sentence: http://t.co/4izCbBod
#
# -
# Input sentence: Crisi
# Decoded sentence: Crisi
#
# -
# Input sentence: ,
# Decoded sentence: ,
#
# -
# Input sentence: Fitch
# Decoded sentence: Fitch
#
# -
# Input sentence: :
# Decoded sentence: :
#
# -
# Input sentence: tagli
# Decoded sentence: tagli
#
# -
# Input sentence: più
# Decoded sentence: più
#
# -
# Input sentence: severi
# Decoded sentence: severi
#
# -
# Input sentence: evitati
# Decoded sentence: evitati
#
# -
# Input sentence: grazie
# Decoded sentence: grazie
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: governo
# Decoded sentence: governo
#
# -
# Input sentence: Monti
# Decoded sentence: Monti
#
# -
# Input sentence: :
# Decoded sentence: :
#
# -
# Input sentence: New
# Decoded sentence: New
#
# -
# Input sentence: York
# Decoded sentence: York
#
# -
# Input sentence: ,
# Decoded sentence: ,
#
# -
# Input sentence: 27
# Decoded sentence: 27
#
# -
# Input sentence: gen
# Decoded sentence: gennaio
#
# -
# Input sentence: .
# Decoded sentence: .
#
# -
# Input sentence: (
# Decoded sentence: (
#
# -
# Input sentence: TMNews
# Decoded sentence: TMNews
#
# -
# Input sentence: )
# Decoded sentence: )
#
# -
# Input sentence: ?
# Decoded sentence: ?
#
# -
# Input sentence: "
# Decoded sentence: "
#
# -
# Input sentence: Un'
# Decoded sentence: Un'
#
# -
# Input sentence: azione
# Decoded sentence: azione
#
# -
# Input sentence: più
# Decoded sentence: più
#
# -
# Input sentence: sever...
# Decoded sentence: severa
#
# -
# Input sentence: http://t.co/noUM2hJi
# Decoded sentence: http://t.co/noUM2hJi
#
# -
# Input sentence: -
# Decoded sentence: -
#
# -
# Input sentence: Mamma
# Decoded sentence: Mamma
#
# -
# Input sentence: domani
# Decoded sentence: domani
#
# -
# Input sentence: torno
# Decoded sentence: torno
#
# -
# Input sentence: .
# Decoded sentence: .
#
# -
# Input sentence: Che
# Decoded sentence: Che
#
# -
# Input sentence: clima
# Decoded sentence: clima
#
# -
# Input sentence: c'
# Decoded sentence: c'
#
# -
# Input sentence: è
# Decoded sentence: è
#
# -
# Input sentence: a
# Decoded sentence: a
#
# -
# Input sentence: Roma
# Decoded sentence: Roma
#
# -
# Input sentence: ?
# Decoded sentence: ?
#
# -
# Input sentence: Fa
# Decoded sentence: Fa
#
# -
# Input sentence: così
# Decoded sentence: così
