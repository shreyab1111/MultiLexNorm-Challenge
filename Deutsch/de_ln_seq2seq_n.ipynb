# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyab1111/MultiLexNorm-Challenge/blob/main/Deutsch/de_ln_seq2seq_n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# German

# %%
batch_size = 64  # Batch size for training.
epochs = 150  # Number of epochs to train for.
latent_dim = 128  # Latent dimensionality of the encoding space.
num_samples = 20000  # Number of samples to train on.
data_path = '/content/drive/MyDrive/NLP/Lexical Normalisation/Multilexnorm Challenge/German/de.train.norm.txt'

# %% [markdown]
# Character encoding

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r") as f:
    lines = f.readlines()
for line in lines[: min(num_samples, len(lines) - 1)]:
  if line=='\n':
    continue
  else:
    input_text, target_text= line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)
# Out:
# Number of samples: 15006
# Number of unique input tokens: 130
# Number of unique output tokens: 130
# Max sequence length for inputs: 35
# Max sequence length for outputs: 38

# %%
input_texts
# Out:
# ['Einer',
#  'bösen',
#  'Kundenmail',
#  'grade',
#  'ganz',
#  'lieb',
#  'und',
#  'nett',
#  'gewantwortet',
#  'ich',
#  'Unser',
#  'Versammlungsleiter',
#  'hat',
#  "'",
#  'Rot-Grün-Schwäche',
#  ',',
#  'das',
#  'hätte',
#  'man',
#  'vor',
#  'der',
#  'Wahl',
#  'wissen',
#  'sollen',
#  '...',
#  'offenbings',
#  'bpt112',
#  'vor',
#  'allem',
#  'machen',
#  'die',
#  'bei',
#  'uns',
#  'so',
#  'ein',
#  'Hype',
#  'darum',
#  ',',
#  'nur',
#  'weils',
#  'heute',
#  'in',
#  'Friedrichshafen',
#  'ist',
#  'Seit',
#  'gestern',
#  'gibts',
#  'auf',
#  'dem',
#  'Stupidozid',
#  'Youtube',
#  'Kanal',
#  'den',
#  'alljährlichen',
#  'Abfallkalender',
#  '.',
#  'Jeden',
#  'tag',
#  'ein',
#  'Türchen',
#  'mit',
#  '...',
#  'oooh',
#  ',',
#  'hab',
#  'ich',
#  'nicht',
#  'gesehn',
#  '.',
#  'wie',
#  'geht',
#  "'s",
#  'dir',
#  '?',
#  '♥',
#  'Morgens',
#  'um',
#  '7',
#  'aufstehen',
#  'um',
#  'irgendwelche',
#  'dubiosen',
#  'Physikarbeiten',
#  'zu',
#  'schreiben',
#  '...',
#  'Wenigstens',
#  'wartet',
#  'ein',
#  'Wundesschöner',
#  'Student',
#  'mit',
#  'mir',
#  'an',
#  'der',
#  'H',
#  'Folgt',
#  'mal',
#  'alle',
#  'der',
#  '@username',
#  '.',
#  'Ihr',
#  'fehlen',
#  'nurnoch',
#  '12',
#  'zu',
#  'den',
#  '500',
#  'Ahh',
#  'die',
#  'Convention',
#  'vom',
#  '8.',
#  '-',
#  '10.',
#  'Juni',
#  'wird',
#  'soo',
#  'total',
#  'genial',
#  '%PosSmiley',
#  'Reisen',
#  'bis',
#  '350',
#  'Euro',
#  'Marmari',
#  'mit',
#  'Tiefpreisgarantie',
#  'TUV',
#  'gepruft',
#  'buchen',
#  '|',
#  'Reisegeier',
#  'Tiefpreisgarantie',
#  '...',
#  'Oh',
#  ',',
#  'top',
#  '!',
#  'Leider',
#  'auch',
#  'seeeehr',
#  'weit',
#  'weg',
#  '%NegSmiley',
#  'Zumindest',
#  'weiss',
#  'ich',
#  'dank',
#  '@username',
#  ',',
#  'dass',
#  'die',
#  'Züribergler',
#  'wegen',
#  'nem',
#  'Laubbläser',
#  'die',
#  'Pozilei',
#  'holen',
#  '.',
#  'Und',
#  'dann',
#  'wiede',
#  '...',
#  'Wer',
#  'weiss',
#  ',',
#  'ob',
#  'man',
#  'auf',
#  '%Link',
#  'oda',
#  'so',
#  '(',
#  'wurscht',
#  'ob',
#  'man',
#  'was',
#  'zahlt',
#  ')',
#  'kapfenberg-rapid',
#  'schaun',
#  'kann',
#  '?',
#  'Höfts',
#  'ma',
#  '!!!!!!!',
#  'Heute',
#  'Finale',
#  '!!!',
#  'Wer',
#  'ist',
#  'Live',
#  'dabei',
#  '??',
#  'Hoffentlich',
#  'gibts',
#  'was',
#  'zu',
#  'feiern',
#  '!!!',
#  '%PosSmiley',
#  'Du',
#  'bist',
#  'echt',
#  'toll',
#  '%PosSmiley',
#  'Ich',
#  'werd',
#  'dran',
#  'denken',
#  '!',
#  'Und',
#  'ihr',
#  'lenkt',
#  'mich',
#  'eh',
#  'grad',
#  'sehr',
#  'ab',
#  '.',
#  'Elektrogeraet',
#  'com',
#  ':',
#  'Ein',
#  'Elektrogeraet',
#  'ist',
#  'ein',
#  'meist',
#  'in',
#  'Privathaushalten',
#  'verwendetes',
#  'Gerat',
#  'Auf',
#  'der',
#  'Seite',
#  'werden',
#  'd',
#  '...',
#  'Brandanschlag',
#  'auf',
#  'Göttinger',
#  'Amtsgericht',
#  ':',
#  'Göttingen',
#  '(',
#  'dapd-nrd',
#  ')',
#  '.',
#  'Nach',
#  'dem',
#  'Brandanschlag',
#  'auf',
#  'das',
#  'Amtsger',
#  '...',
#  '%Link',
#  'goettingen',
#  'Costa',
#  'Rica',
#  'und',
#  'Lappland',
#  'siegten',
#  '-',
#  'Badische',
#  'Zeitung',
#  ':',
#  'Badische',
#  'Zeitung',
#  'Costa',
#  'Rica',
#  'und',
#  'Lappland',
#  'siegten',
#  'Badische',
#  'Zeit',
#  '...',
#  'weiste',
#  'lisa',
#  'kann',
#  'kötz',
#  'auch',
#  'gut',
#  'leiden',
#  'un',
#  'zu',
#  'der',
#  'sagst',
#  'du',
#  'nix',
#  'rofl',
#  '!',
#  'ich',
#  'bin',
#  'auf',
#  'nem',
#  'Argentinischen',
#  'Ts',
#  'und',
#  'zeige',
#  'denen',
#  'Lalas',
#  '..',
#  'wat',
#  'machen',
#  'die',
#  '?',
#  'die',
#  'lalan',
#  'mit',
#  '%PosSmiley',
#  'Was',
#  'ich',
#  'jetzt',
#  'brauche',
#  ':',
#  'ganz',
#  'viel',
#  'Katzenkuscheln',
#  ',',
#  'Schokolade',
#  ',',
#  'Bett',
#  ',',
#  'Wärme',
#  ',',
#  'Kakao',
#  ',',
#  'Musik',
#  ',',
#  'Zeit',
#  ',',
#  'Ruhe',
#  '.',
#  'Oder',
#  ',',
#  'was',
#  'noch',
#  'vi',
#  '...',
#  'Domian',
#  '-',
#  'Janine',
#  'sollte',
#  'nächste',
#  'Woche',
#  'gaaaanz',
#  'genau',
#  'zuhören',
#  '!',
#  'Da',
#  'geht',
#  'ihr',
#  'einer',
#  'ab',
#  '...',
#  '(',
#  'Schämen',
#  'für',
#  'Partner',
#  ')',
#  'ich',
#  'habs',
#  'gelesen',
#  '%PosSmiley',
#  'ohh',
#  'gooott',
#  'ich',
#  'will',
#  'auch',
#  'so',
#  'nen',
#  'typen',
#  'aber',
#  'meiner',
#  'braucht',
#  'nen',
#  'arschtritt',
#  '&gt;',
#  '&lt;',
#  'Und',
#  'ver',
#  'schnart',
#  'mehr',
#  'vie',
#  'du',
#  '..',
#  'Lieba',
#  'ich',
#  'bin',
#  'noch',
#  'gnadich',
#  '..',
#  'Mir',
#  'habn',
#  'heint',
#  'schon',
#  'tietela',
#  'mocht',
#  '..',
#  'Das',
#  'is',
#  'grauslich',
#  'zu',
#  '..',
#  'Lmao',
#  '..',
#  'Vertriebsmitarbeiter/in',
#  ':',
#  'Radolfzell',
#  'am',
#  'Bodensee',
#  '|',
#  'Tätigkeits-Schwerpunkt',
#  '...',
#  'Das',
#  'Unternehmen',
#  'sucht',
#  'in',
#  'Radolfzell',
#  '...',
#  'jaaaaaaa',
#  'ich',
#  'meckere',
#  'nciht',
#  'ich',
#  'weise',
#  'dich',
#  'nur',
#  'drauf',
#  'hin',
#  '%PosSmiley',
#  'Informationsfilm',
#  '"',
#  'Revisionssicheres',
#  'Berechtigungsmanagement',
#  '"',
#  ':',
#  'Zentrales',
#  'Berechtigungsmanagement',
#  'ist',
#  'die',
#  'Basis',
#  'fü',
#  '...',
#  'Achso',
#  '!',
#  'Er',
#  'ist',
#  'fehlerfrei',
#  '!..',
#  'Nur',
#  'passiert',
#  'das',
#  'Ansprechen',
#  'in',
#  'der',
#  'Möglichkeitsform',
#  'und',
#  'nicht',
#  'in',
#  'der',
#  'Wirklichkeitsfrom',
#  '...',
#  'das',
#  'ist',
#  'schade',
#  'ach',
#  ',',
#  'hört',
#  'uff',
#  '.',
#  'ich',
#  'kenn',
#  'euch',
#  'doch',
#  'Ich',
#  'bin',
#  'Naturgeil',
#  'veranlagt',
#  'bei',
#  'mir',
#  'gibts',
#  'den',
#  'geilen',
#  'Sex',
#  ':',
#  'Neu',
#  ',',
#  'Nina',
#  '(',
#  '35',
#  ')',
#  '*',
#  'Zürich',
#  '*',
#  'Ich',
#  'bin',
#  '...',
#  'Achso',
#  '?',
#  'Naja',
#  ',',
#  'in',
#  '22',
#  'Tagen',
#  'ist',
#  'ja',
#  'schon',
#  'Weihnachten',
#  '...',
#  'British',
#  'Langhaar',
#  'BKH',
#  'Zucht',
#  'in',
#  'Gold',
#  '&',
#  'Silber',
#  '%PosSmiley',
#  'in',
#  'Hamburg',
#  ':',
#  'Wir',
#  'sind',
#  'eine',
#  'liebevolle',
#  'und',
#  'seriö',
#  '...',
#  '%Link',
#  'Anzeigen',
#  'Machen',
#  'wir',
#  'uns',
#  'nix',
#  'vor',
#  ',',
#  'am',
#  'heutige',
#  'Tach',
#  'können',
#  'wir',
#  'alle',
#  'live',
#  'dabei',
#  'zuguckn',
#  'wie',
#  'unser',
#  'aller',
#  'Kindheit',
#  'endgültig',
#  'zu',
#  'End',
#  '...',
#  '%PosSmiley',
#  '%PosSmiley',
#  'na',
#  ',',
#  'leida',
#  'ned',
#  ',',
#  'sie',
#  'melden',
#  'sich',
#  'irgendwann',
#  'bis',
#  'neujahr',
#  ',',
#  'also',
#  'könnts',
#  'noch',
#  'dauern',
#  '%NegSmiley',
#  'ich',
#  'geh',
#  'jz',
#  'dann',
#  'schlafen',
#  '%PosSmiley',
#  'gute',
#  'nacht',
#  'Haha',
#  '%PosSmiley',
#  'Also',
#  'wenn',
#  'du',
#  'noch',
#  'Hilfe',
#  'brauchst',
#  ',',
#  'schau',
#  'ich',
#  'auch',
#  'gerne',
#  'mal',
#  'drüber',
#  '%PosSmiley',
#  'nich',
#  'viel',
#  '2',
#  ',',
#  'kann',
#  'davon',
#  'doch',
#  'nich',
#  'so',
#  'viel',
#  'trinken',
#  'fructose',
#  'So',
#  'jetzt',
#  'siehste',
#  'ihn',
#  'auch',
#  'so',
#  '%PosSmiley',
#  '%Link',
#  'Find',
#  'ich',
#  'aber',
#  'auch',
#  '!',
#  '%NegSmiley',
#  'Wer',
#  'erlebt',
#  'versteht',
#  ':',
#  'wie',
#  'Salz',
#  'und',
#  'Pfeffer',
#  'fur',
#  'Ihre',
#  'Events',
#  'Salz',
#  'fur',
#  'ein',
#  'gutes',
#  'Ergebnis',
#  'wertvoll',
#  'und',
#  'unverzi',
#  '...',
#  'Werd',
#  'ich',
#  'machen',
#  '%PosSmiley',
#  'Durch',
#  'langjhrigen',
#  'Erfahrungen',
#  'knnen',
#  'wir',
#  'Casinos',
#  'empfehlen',
#  ',',
#  'die',
#  'Deutsches',
#  'Online',
#  'Casino',
#  'gerecht',
#  'werden',
#  '.',
#  'Bete',
#  'grade',
#  'zur',
#  'kvb',
#  ',',
#  'dass',
#  'es',
#  'wenigstens',
#  'jetzt',
#  'keine',
#  'störungen',
#  'gibt',
#  '...',
#  'Sass',
#  'vorhin',
#  'schon',
#  'ne',
#  'stunde',
#  'länger',
#  'in',
#  'der',
#  'bahn',
#  '%PosSmiley',
#  'soooo',
#  'schön',
#  '!',
#  'Und',
#  'Berlin',
#  '!',
#  '"',
#  'zum',
#  'Start',
#  'in',
#  'den',
#  'Morgen',
#  'Marlon',
#  'Roudette',
#  'New',
#  'Age',
#  'http://t.co/rGDUVl87',
#  '"',
#  'Oh',
#  ',',
#  'in',
#  'der',
#  'Stadthalle',
#  'in',
#  'Offenbach',
#  'scheint',
#  'heute',
#  "'",
#  'Erotikmesse',
#  'zu',
#  'sein',
#  '.',
#  'Endlose',
#  'Schlangen',
#  'junger',
#  'Männer',
#  '.',
#  'Also',
#  'ich',
#  'mache',
#  'grad',
#  'den',
#  'mit',
#  'der',
#  'Schlange',
#  ',',
#  'ne',
#  '...',
#  'Toll',
#  ',',
#  'T3',
#  'und',
#  'der',
#  'mit',
#  'der',
#  'Schlange',
#  'sind',
#  'die',
#  'längsten',
#  '%PosSmiley',
#  'Nur',
#  'vicodin',
#  'fuer',
#  'arme',
#  '-',
#  'goldbrand',
#  'und',
#  'beerenwein',
#  '.',
#  'Bola',
#  'mulu',
#  '..',
#  '%NegSmiley',
#  'Semoga',
#  'SPANYOL',
#  ',',
#  'JERMAN',
#  ',',
#  'PORTUGAL',
#  ',',
#  'PRANCIS',
#  'satu',
#  'grup',
#  '..',
#  'Deutschland',
#  'Uber',
#  'Alles',
#  '!!',
#  'ich',
#  'hab',
#  'nix',
#  'bekommen',
#  ',',
#  'kann',
#  'das',
#  'sein',
#  'das',
#  'das',
#  'ne',
#  'andere',
#  'war',
#  ':)',
#  '?',
#  'das',
#  'würde',
#  'dann',
#  'auch',
#  'klären',
#  'warum',
#  'du',
#  'mich',
#  'hübschfindest',
#  ':',
#  '%NegSmiley',
#  ')',
#  'Aber',
#  'so',
#  'ein',
#  'bisschen',
#  'wirkt',
#  'das',
#  'wie',
#  'ein',
#  'gemeinsamer',
#  'Kongress',
#  'von',
#  'Julis',
#  ',',
#  'Grüner',
#  'Jugend',
#  'und',
#  'Grünen',
#  'in',
#  'der',
#  'Gründungsphas',
#  '...',
#  'ja',
#  'wieso',
#  'wohl',
#  ":'DD",
#  'nur',
#  'wegn',
#  'dir',
#  'bin',
#  'auch',
#  'so',
#  'gwordn',
#  'Wenn',
#  'ich',
#  'mein',
#  'Abi',
#  'schaffe',
#  ',',
#  'blüht',
#  'mir',
#  'ne',
#  'goldene',
#  'Zukunft',
#  '!',
#  'wie',
#  'kommt',
#  'an',
#  'auf',
#  'so',
#  'ne',
#  'wette',
#  '?',
#  'keine',
#  'freunde',
#  '?',
#  'keinen',
#  'stecher',
#  '?',
#  'kein',
#  'twitter',
#  '?',
#  'wettendass',
#  'Wenn',
#  'du',
#  'dich',
#  'zwischen',
#  'Freundschaft',
#  'oder',
#  'Liebe',
#  'entscheiden',
#  'musst',
#  ',',
#  'wähle',
#  'stehts',
#  'die',
#  'Freundschaft',
#  'LoveLiveLaugh_2',
#  'ich',
#  'lern',
#  'jetzt',
#  'noch',
#  ',',
#  'klein',
#  'bisschen',
#  'Zeit',
#  'hab',
#  'ich',
#  'ja',
#  'noch',
#  '.',
#  'CH',
#  ':',
#  'ESCORT',
#  '24',
#  'ANFANGERIN',
#  'TEENY',
#  ':',
#  'FRUSINA',
#  'Ich',
#  'bin',
#  'eine',
#  'heisse',
#  'teeny18j',
#  'naturgeile',
#  'sympathische',
#  'Schoenheit',
#  'mit',
#  '...',
#  '%PosSmiley',
#  'sry',
#  'mäuschen',
#  ',',
#  'das',
#  'wird',
#  'nix',
#  '.',
#  'Wir',
#  'sind',
#  'musiker',
#  'und',
#  'ficken',
#  'nur',
#  'dumme',
#  'frauen',
#  '.',
#  'Britischer',
#  'Premier',
#  'trifft',
#  'Sarkozy',
#  ':',
#  'Cameron',
#  'fordert',
#  '"',
#  'Bazooka-Einsatz',
#  '"',
#  'gegen',
#  'Krise',
#  ':',
#  'Auftritt',
#  'der',
#  'dritten',
#  'EU-Grossma',
#  '...',
#  'VTV',
#  'Versicherungen',
#  'Treuhand',
#  'Villars',
#  ':',
#  'Informationen',
#  'uber',
#  'die',
#  'angebotenen',
#  'Dienstleistungen',
#  'und',
#  'Produkte',
#  'rund',
#  'um',
#  'di',
#  '...',
#  'vor',
#  '2',
#  'stunden',
#  'oder',
#  'so',
#  '%PosSmiley',
#  'wäääääääh',
#  'ich',
#  'renn',
#  'gleeich',
#  'weeg',
#  '...',
#  '%PosSmiley',
#  'Kannste',
#  'mal',
#  'den',
#  'Typ',
#  'fragen',
#  ',',
#  'der',
#  'die',
#  'Ausschreibung',
#  'gemacht',
#  'hat',
#  '%PosSmiley',
#  '?',
#  'ach',
#  '.',
#  'Da',
#  'basteln',
#  'wir',
#  'was',
#  'schönes',
#  'draus',
#  '.',
#  '%PosSmiley',
#  'Was',
#  'ist',
#  ...]

# %% [markdown]
# encoder_input_data is a 3D array of shape (num_pairs, max_english_sentence_length, num_english_characters) containing a one-hot vectorization of the English sentences.
#
# decoder_input_data is a 3D array of shape (num_pairs, max_french_sentence_length, num_french_characters) containg a one-hot vectorization of the French sentences.
#
# decoder_target_data is the same as decoder_input_data but offset by one timestep. decoder_target_data[:, t, :] will be the same as decoder_input_data[:, t + 1, :].

# %%
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

# %% [markdown]
# one hot rep

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[',']] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, (t + 1):, target_token_index[',']] = 1.0
    decoder_target_data[i, t:, target_token_index[',']] = 1.0

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/150
# 188/188 [==============================] - 15s 38ms/step - loss: 0.6710 - accuracy: 0.8504 - val_loss: 0.4711 - val_accuracy: 0.8716
# Epoch 2/150
# 188/188 [==============================] - 6s 32ms/step - loss: 0.4300 - accuracy: 0.8884 - val_loss: 0.3697 - val_accuracy: 0.9057
# Epoch 3/150
# 188/188 [==============================] - 6s 32ms/step - loss: 0.3553 - accuracy: 0.9061 - val_loss: 0.3381 - val_accuracy: 0.9073
# Epoch 4/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.3379 - accuracy: 0.9089 - val_loss: 0.3210 - val_accuracy: 0.9125
# Epoch 5/150
# 188/188 [==============================] - 6s 32ms/step - loss: 0.3177 - accuracy: 0.9123 - val_loss: 0.2968 - val_accuracy: 0.9170
# Epoch 6/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.2972 - accuracy: 0.9171 - val_loss: 0.2851 - val_accuracy: 0.9200
# Epoch 7/150
# 188/188 [==============================] - 6s 32ms/step - loss: 0.2837 - accuracy: 0.9208 - val_loss: 0.2781 - val_accuracy: 0.9206
# Epoch 8/150
# 188/188 [==============================] - 6s 32ms/step - loss: 0.2672 - accuracy: 0.9258 - val_loss: 0.2642 - val_accuracy: 0.9263
# Epoch 9/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.2475 - accuracy: 0.9316 - val_loss: 0.2400 - val_accuracy: 0.9345
# Epoch 10/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.2317 - accuracy: 0.9365 - val_loss: 0.2247 - val_accuracy: 0.9393
# Epoch 11/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.2189 - accuracy: 0.9401 - val_loss: 0.2185 - val_accuracy: 0.9406
# Epoch 12/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.2072 - accuracy: 0.9435 - val_loss: 0.2106 - val_accuracy: 0.9432
# Epoch 13/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1962 - accuracy: 0.9464 - val_loss: 0.2010 - val_accuracy: 0.9467
# Epoch 14/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1866 - accuracy: 0.9490 - val_loss: 0.1877 - val_accuracy: 0.9497
# Epoch 15/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1781 - accuracy: 0.9516 - val_loss: 0.1881 - val_accuracy: 0.9491
# Epoch 16/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1697 - accuracy: 0.9537 - val_loss: 0.1753 - val_accuracy: 0.9534
# Epoch 17/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1621 - accuracy: 0.9558 - val_loss: 0.1679 - val_accuracy: 0.9554
# Epoch 18/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1548 - accuracy: 0.9578 - val_loss: 0.1630 - val_accuracy: 0.9556
# Epoch 19/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1475 - accuracy: 0.9599 - val_loss: 0.1656 - val_accuracy: 0.9549
# Epoch 20/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1415 - accuracy: 0.9615 - val_loss: 0.1515 - val_accuracy: 0.9599
# Epoch 21/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1350 - accuracy: 0.9632 - val_loss: 0.1469 - val_accuracy: 0.9601
# Epoch 22/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1291 - accuracy: 0.9647 - val_loss: 0.1389 - val_accuracy: 0.9635
# Epoch 23/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1238 - accuracy: 0.9660 - val_loss: 0.1410 - val_accuracy: 0.9626
# Epoch 24/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1185 - accuracy: 0.9675 - val_loss: 0.1296 - val_accuracy: 0.9662
# Epoch 25/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.1129 - accuracy: 0.9691 - val_loss: 0.1314 - val_accuracy: 0.9657
# Epoch 26/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.1081 - accuracy: 0.9704 - val_loss: 0.1307 - val_accuracy: 0.9654
# Epoch 27/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.1030 - accuracy: 0.9717 - val_loss: 0.1273 - val_accuracy: 0.9666
# Epoch 28/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0985 - accuracy: 0.9730 - val_loss: 0.1176 - val_accuracy: 0.9697
# Epoch 29/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.0936 - accuracy: 0.9745 - val_loss: 0.1210 - val_accuracy: 0.9685
# Epoch 30/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0892 - accuracy: 0.9756 - val_loss: 0.1195 - val_accuracy: 0.9691
# Epoch 31/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.0852 - accuracy: 0.9767 - val_loss: 0.1143 - val_accuracy: 0.9707
# Epoch 32/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.0807 - accuracy: 0.9780 - val_loss: 0.1166 - val_accuracy: 0.9700
# Epoch 33/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0768 - accuracy: 0.9791 - val_loss: 0.1043 - val_accuracy: 0.9736
# Epoch 34/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.0730 - accuracy: 0.9800 - val_loss: 0.1051 - val_accuracy: 0.9731
# Epoch 35/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0695 - accuracy: 0.9811 - val_loss: 0.1015 - val_accuracy: 0.9749
# Epoch 36/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0660 - accuracy: 0.9821 - val_loss: 0.1046 - val_accuracy: 0.9734
# Epoch 37/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0628 - accuracy: 0.9830 - val_loss: 0.0964 - val_accuracy: 0.9761
# Epoch 38/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0599 - accuracy: 0.9837 - val_loss: 0.1110 - val_accuracy: 0.9722
# Epoch 39/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0574 - accuracy: 0.9845 - val_loss: 0.1005 - val_accuracy: 0.9750
# Epoch 40/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.0545 - accuracy: 0.9853 - val_loss: 0.1019 - val_accuracy: 0.9749
# Epoch 41/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0518 - accuracy: 0.9861 - val_loss: 0.0925 - val_accuracy: 0.9772
# Epoch 42/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0496 - accuracy: 0.9867 - val_loss: 0.0970 - val_accuracy: 0.9773
# Epoch 43/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.0475 - accuracy: 0.9873 - val_loss: 0.0982 - val_accuracy: 0.9764
# Epoch 44/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0450 - accuracy: 0.9879 - val_loss: 0.0944 - val_accuracy: 0.9774
# Epoch 45/150
# 188/188 [==============================] - 6s 31ms/step - loss: 0.0429 - accuracy: 0.9885 - val_loss: 0.0913 - val_accuracy: 0.9784
# Epoch 46/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0412 - accuracy: 0.9888 - val_loss: 0.0975 - val_accuracy: 0.9775
# Epoch 47/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0394 - accuracy: 0.9894 - val_loss: 0.0985 - val_accuracy: 0.9768
# Epoch 48/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0378 - accuracy: 0.9898 - val_loss: 0.0925 - val_accuracy: 0.9783
# Epoch 49/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0359 - accuracy: 0.9904 - val_loss: 0.0914 - val_accuracy: 0.9789
# Epoch 50/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0346 - accuracy: 0.9907 - val_loss: 0.0916 - val_accuracy: 0.9790
# Epoch 51/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0330 - accuracy: 0.9912 - val_loss: 0.0918 - val_accuracy: 0.9789
# Epoch 52/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0319 - accuracy: 0.9915 - val_loss: 0.0899 - val_accuracy: 0.9794
# Epoch 53/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0303 - accuracy: 0.9919 - val_loss: 0.0952 - val_accuracy: 0.9787
# Epoch 54/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0292 - accuracy: 0.9923 - val_loss: 0.0977 - val_accuracy: 0.9786
# Epoch 55/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0283 - accuracy: 0.9924 - val_loss: 0.0911 - val_accuracy: 0.9797
# Epoch 56/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0271 - accuracy: 0.9928 - val_loss: 0.0904 - val_accuracy: 0.9796
# Epoch 57/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0261 - accuracy: 0.9931 - val_loss: 0.0914 - val_accuracy: 0.9801
# Epoch 58/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0249 - accuracy: 0.9936 - val_loss: 0.1022 - val_accuracy: 0.9775
# Epoch 59/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0243 - accuracy: 0.9937 - val_loss: 0.0915 - val_accuracy: 0.9802
# Epoch 60/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0233 - accuracy: 0.9940 - val_loss: 0.0941 - val_accuracy: 0.9796
# Epoch 61/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0223 - accuracy: 0.9943 - val_loss: 0.0933 - val_accuracy: 0.9802
# Epoch 62/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0214 - accuracy: 0.9946 - val_loss: 0.0934 - val_accuracy: 0.9802
# Epoch 63/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0208 - accuracy: 0.9946 - val_loss: 0.0929 - val_accuracy: 0.9806
# Epoch 64/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0201 - accuracy: 0.9949 - val_loss: 0.0943 - val_accuracy: 0.9801
# Epoch 65/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0194 - accuracy: 0.9950 - val_loss: 0.0931 - val_accuracy: 0.9806
# Epoch 66/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0189 - accuracy: 0.9952 - val_loss: 0.0945 - val_accuracy: 0.9808
# Epoch 67/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0180 - accuracy: 0.9954 - val_loss: 0.0957 - val_accuracy: 0.9803
# Epoch 68/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0175 - accuracy: 0.9956 - val_loss: 0.0937 - val_accuracy: 0.9807
# Epoch 69/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0170 - accuracy: 0.9957 - val_loss: 0.1002 - val_accuracy: 0.9794
# Epoch 70/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0165 - accuracy: 0.9959 - val_loss: 0.0964 - val_accuracy: 0.9806
# Epoch 71/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0161 - accuracy: 0.9960 - val_loss: 0.0958 - val_accuracy: 0.9808
# Epoch 72/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0156 - accuracy: 0.9961 - val_loss: 0.0961 - val_accuracy: 0.9809
# Epoch 73/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0156 - accuracy: 0.9961 - val_loss: 0.0979 - val_accuracy: 0.9808
# Epoch 74/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0148 - accuracy: 0.9963 - val_loss: 0.1007 - val_accuracy: 0.9799
# Epoch 75/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0142 - accuracy: 0.9965 - val_loss: 0.0970 - val_accuracy: 0.9807
# Epoch 76/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0138 - accuracy: 0.9965 - val_loss: 0.0976 - val_accuracy: 0.9812
# Epoch 77/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0136 - accuracy: 0.9966 - val_loss: 0.0987 - val_accuracy: 0.9810
# Epoch 78/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0133 - accuracy: 0.9967 - val_loss: 0.1001 - val_accuracy: 0.9804
# Epoch 79/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0129 - accuracy: 0.9968 - val_loss: 0.1058 - val_accuracy: 0.9799
# Epoch 80/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0126 - accuracy: 0.9969 - val_loss: 0.1008 - val_accuracy: 0.9809
# Epoch 81/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0124 - accuracy: 0.9970 - val_loss: 0.1028 - val_accuracy: 0.9807
# Epoch 82/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.1025 - val_accuracy: 0.9802
# Epoch 83/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 0.1079 - val_accuracy: 0.9799
# Epoch 84/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0115 - accuracy: 0.9972 - val_loss: 0.1015 - val_accuracy: 0.9812
# Epoch 85/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0111 - accuracy: 0.9972 - val_loss: 0.1042 - val_accuracy: 0.9809
# Epoch 86/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.1044 - val_accuracy: 0.9806
# Epoch 87/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0108 - accuracy: 0.9973 - val_loss: 0.1035 - val_accuracy: 0.9809
# Epoch 88/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0107 - accuracy: 0.9973 - val_loss: 0.1026 - val_accuracy: 0.9810
# Epoch 89/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 0.1060 - val_accuracy: 0.9804
# Epoch 90/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0101 - accuracy: 0.9974 - val_loss: 0.1045 - val_accuracy: 0.9805
# Epoch 91/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0101 - accuracy: 0.9975 - val_loss: 0.1047 - val_accuracy: 0.9809
# Epoch 92/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0098 - accuracy: 0.9975 - val_loss: 0.1053 - val_accuracy: 0.9812
# Epoch 93/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.1067 - val_accuracy: 0.9807
# Epoch 94/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0095 - accuracy: 0.9976 - val_loss: 0.1058 - val_accuracy: 0.9810
# Epoch 95/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0096 - accuracy: 0.9976 - val_loss: 0.1052 - val_accuracy: 0.9812
# Epoch 96/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0092 - accuracy: 0.9977 - val_loss: 0.1041 - val_accuracy: 0.9815
# Epoch 97/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 0.1052 - val_accuracy: 0.9815
# Epoch 98/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.1069 - val_accuracy: 0.9811
# Epoch 99/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.1092 - val_accuracy: 0.9810
# Epoch 100/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0088 - accuracy: 0.9977 - val_loss: 0.1093 - val_accuracy: 0.9809
# Epoch 101/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0085 - accuracy: 0.9979 - val_loss: 0.1072 - val_accuracy: 0.9811
# Epoch 102/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.1074 - val_accuracy: 0.9810
# Epoch 103/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.1113 - val_accuracy: 0.9803
# Epoch 104/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.1089 - val_accuracy: 0.9810
# Epoch 105/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.1092 - val_accuracy: 0.9812
# Epoch 106/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.1073 - val_accuracy: 0.9814
# Epoch 107/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.1111 - val_accuracy: 0.9814
# Epoch 108/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.1111 - val_accuracy: 0.9811
# Epoch 109/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.1083 - val_accuracy: 0.9816
# Epoch 110/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0078 - accuracy: 0.9981 - val_loss: 0.1120 - val_accuracy: 0.9809
# Epoch 111/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.1090 - val_accuracy: 0.9814
# Epoch 112/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.1121 - val_accuracy: 0.9808
# Epoch 113/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.1129 - val_accuracy: 0.9812
# Epoch 114/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.1115 - val_accuracy: 0.9808
# Epoch 115/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.1114 - val_accuracy: 0.9811
# Epoch 116/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.1143 - val_accuracy: 0.9813
# Epoch 117/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.1131 - val_accuracy: 0.9813
# Epoch 118/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.1124 - val_accuracy: 0.9815
# Epoch 119/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0069 - accuracy: 0.9981 - val_loss: 0.1129 - val_accuracy: 0.9813
# Epoch 120/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0069 - accuracy: 0.9982 - val_loss: 0.1114 - val_accuracy: 0.9815
# Epoch 121/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.1114 - val_accuracy: 0.9818
# Epoch 122/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.1149 - val_accuracy: 0.9803
# Epoch 123/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.1125 - val_accuracy: 0.9817
# Epoch 124/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.1138 - val_accuracy: 0.9811
# Epoch 125/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.1151 - val_accuracy: 0.9811
# Epoch 126/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.1136 - val_accuracy: 0.9815
# Epoch 127/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.1150 - val_accuracy: 0.9813
# Epoch 128/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.1138 - val_accuracy: 0.9812
# Epoch 129/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.1149 - val_accuracy: 0.9814
# Epoch 130/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.1166 - val_accuracy: 0.9814
# Epoch 131/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.1156 - val_accuracy: 0.9814
# Epoch 132/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.1152 - val_accuracy: 0.9816
# Epoch 133/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.1134 - val_accuracy: 0.9820
# Epoch 134/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.1163 - val_accuracy: 0.9812
# Epoch 135/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.1155 - val_accuracy: 0.9813
# Epoch 136/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.1164 - val_accuracy: 0.9814
# Epoch 137/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.1162 - val_accuracy: 0.9811
# Epoch 138/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.1160 - val_accuracy: 0.9815
# Epoch 139/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.1149 - val_accuracy: 0.9815
# Epoch 140/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.1193 - val_accuracy: 0.9810
# Epoch 141/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.1182 - val_accuracy: 0.9813
# Epoch 142/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.1183 - val_accuracy: 0.9815
# Epoch 143/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.1170 - val_accuracy: 0.9814
# Epoch 144/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.1187 - val_accuracy: 0.9812
# Epoch 145/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.1171 - val_accuracy: 0.9813
# Epoch 146/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.1196 - val_accuracy: 0.9814
# Epoch 147/150
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.1186 - val_accuracy: 0.9812
# Epoch 148/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.1182 - val_accuracy: 0.9813
# Epoch 149/150
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.1182 - val_accuracy: 0.9815
# Epoch 150/150
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.1189 - val_accuracy: 0.9816
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2s/assets
# INFO:tensorflow:Assets written to: s2s/assets

# %%
from tensorflow.keras.utils import plot_model
plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)

# %% [markdown]
# testing with validation

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,), name="input_6")
decoder_state_input_c = keras.Input(shape=(latent_dim,), name="input_5")
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: Einer
# Decoded sentence: Einer
#
# -
# Input sentence: bösen
# Decoded sentence: bösen
#
# -
# Input sentence: Kundenmail
# Decoded sentence: Kundenmail
#
# -
# Input sentence: grade
# Decoded sentence: gerade
#
# -
# Input sentence: ganz
# Decoded sentence: ganz
#
# -
# Input sentence: lieb
# Decoded sentence: lieb
#
# -
# Input sentence: und
# Decoded sentence: und
#
# -
# Input sentence: nett
# Decoded sentence: nett
#
# -
# Input sentence: gewantwortet
# Decoded sentence: geantwortet
#
# -
# Input sentence: ich
# Decoded sentence: ich
#
# -
# Input sentence: Unser
# Decoded sentence: Unser
#
# -
# Input sentence: Versammlungsleiter
# Decoded sentence: Versammlungsleiter
#
# -
# Input sentence: hat
# Decoded sentence: hat
#
# -
# Input sentence: '
# Decoded sentence: '
#
# -
# Input sentence: Rot-Grün-Schwäche
# Decoded sentence: Rot-Grün-Schwäche
#
# -
# Input sentence: ,
# Decoded sentence: ,
#
# -
# Input sentence: das
# Decoded sentence: das
#
# -
# Input sentence: hätte
# Decoded sentence: hätte
#
# -
# Input sentence: man
# Decoded sentence: man
#
# -
# Input sentence: vor
# Decoded sentence: vor
#
# -
# Input sentence: der
# Decoded sentence: der
#
# -
# Input sentence: Wahl
# Decoded sentence: Wahl
#
# -
# Input sentence: wissen
# Decoded sentence: wissen
#
# -
# Input sentence: sollen
# Decoded sentence: sollen
#
# -
# Input sentence: ...
# Decoded sentence: ...
#
# -
# Input sentence: offenbings
# Decoded sentence: offenbings
#
# -
# Input sentence: bpt112
# Decoded sentence: bpt112
#
# -
# Input sentence: vor
# Decoded sentence: vor
#
# -
# Input sentence: allem
# Decoded sentence: allem
#
# -
# Input sentence: machen
# Decoded sentence: machen
#
# -
# Input sentence: die
# Decoded sentence: die
#
# -
# Input sentence: bei
# Decoded sentence: bei
#
# -
# Input sentence: uns
# Decoded sentence: uns
#
# -
# Input sentence: so
# Decoded sentence: so
#
# -
# Input sentence: ein
# Decoded sentence: ein
#
# -
# Input sentence: Hype
# Decoded sentence: Hype
#
# -
# Input sentence: darum
# Decoded sentence: daraum
#
# -
# Input sentence: ,
# Decoded sentence: ,
#
# -
# Input sentence: nur
# Decoded sentence: nur
#
# -
# Input sentence: weils
# Decoded sentence: weil es
#
# -
# Input sentence: heute
# Decoded sentence: heute
#
# -
# Input sentence: in
# Decoded sentence: in
#
# -
# Input sentence: Friedrichshafen
# Decoded sentence: Friedrichshafen
#
# -
# Input sentence: ist
# Decoded sentence: ist
#
# -
# Input sentence: Seit
# Decoded sentence: Seit
#
# -
# Input sentence: gestern
# Decoded sentence: gestern
#
# -
# Input sentence: gibts
# Decoded sentence: gibt es
#
# -
# Input sentence: auf
# Decoded sentence: auf
#
# -
# Input sentence: dem
# Decoded sentence: dem
#
# -
# Input sentence: Stupidozid
# Decoded sentence: Stupidozid
#
# -
# Input sentence: Youtube
# Decoded sentence: Youtube
#
# -
# Input sentence: Kanal
# Decoded sentence: Kanal
#
# -
# Input sentence: den
# Decoded sentence: den
#
# -
# Input sentence: alljährlichen
# Decoded sentence: alljährlichen
#
# -
# Input sentence: Abfallkalender
# Decoded sentence: Abfallkalender
#
# -
# Input sentence: .
# Decoded sentence: .
#
# -
# Input sentence: Jeden
# Decoded sentence: Jeden
#
# -
# Input sentence: tag
# Decoded sentence: Tag
#
# -
# Input sentence: ein
# Decoded sentence: ein
#
# -
# Input sentence: Türchen
# Decoded sentence: Türchen
#
# -
# Input sentence: mit
# Decoded sentence: mit
#
# -
# Input sentence: ...
# Decoded sentence: ...
#
# -
# Input sentence: oooh
# Decoded sentence: Oooh
#
# -
# Input sentence: ,
# Decoded sentence: ,
#
# -
# Input sentence: hab
# Decoded sentence: habe
#
# -
# Input sentence: ich
# Decoded sentence: ich
#
# -
# Input sentence: nicht
# Decoded sentence: nicht
#
# -
# Input sentence: gesehn
# Decoded sentence: gesehen
#
# -
# Input sentence: .
# Decoded sentence: .
#
# -
# Input sentence: wie
# Decoded sentence: wie
#
# -
# Input sentence: geht
# Decoded sentence: geht
#
# -
# Input sentence: 's
# Decoded sentence: das
#
# -
# Input sentence: dir
# Decoded sentence: dir
#
# -
# Input sentence: ?
# Decoded sentence: ?
#
# -
# Input sentence: ♥
# Decoded sentence: ♥
#
# -
# Input sentence: Morgens
# Decoded sentence: Morgens
#
# -
# Input sentence: um
# Decoded sentence: um
#
# -
# Input sentence: 7
# Decoded sentence: 7
#
# -
# Input sentence: aufstehen
# Decoded sentence: aufstehen
#
# -
# Input sentence: um
# Decoded sentence: um
#
# -
# Input sentence: irgendwelche
# Decoded sentence: irgendwelche
#
# -
# Input sentence: dubiosen
# Decoded sentence: dubiosen
#
# -
# Input sentence: Physikarbeiten
# Decoded sentence: Physikarbeiten
#
# -
# Input sentence: zu
# Decoded sentence: zu
#
# -
# Input sentence: schreiben
# Decoded sentence: schreiben
#
# -
# Input sentence: ...
# Decoded sentence: ...
#
# -
# Input sentence: Wenigstens
# Decoded sentence: Wenigstens
#
# -
# Input sentence: wartet
# Decoded sentence: wartet
#
# -
# Input sentence: ein
# Decoded sentence: ein
#
# -
# Input sentence: Wundesschöner
# Decoded sentence: wunderschöner
#
# -
# Input sentence: Student
# Decoded sentence: Student
#
# -
# Input sentence: mit
# Decoded sentence: mit
#
# -
# Input sentence: mir
# Decoded sentence: mir
#
# -
# Input sentence: an
# Decoded sentence: an
#
# -
# Input sentence: der
# Decoded sentence: der
#
# -
# Input sentence: H
# Decoded sentence: H
#
# -
# Input sentence: Folgt
# Decoded sentence: Folgt
#
# -
# Input sentence: mal
# Decoded sentence: mal
#
# -
# Input sentence: alle
# Decoded sentence: alle
#
# -
# Input sentence: der
# Decoded sentence: der
